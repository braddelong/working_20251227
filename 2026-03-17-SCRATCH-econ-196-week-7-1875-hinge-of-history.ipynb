# %% [markdown]
# ### Econ 196 Seminar: Quantitative Long-Run Global Economic History
#
# # WEEK 7: 1875 as the Most Significant Hinge of Economic History
#
# <p style="text-align: right;">
#     <img src="images/delong-picture.png"
#      alt="J. Bradford DeLong"
#      width="300"
#      height="300"
#      align="right"
#      style="float:right; margin: 0 0 10px 10px;" />
# </p>
#
# #### J. Bradford DeLong :: delong@econ.berkeley.edu brad.delong@gmail.com delong@hey.com :: +1-925-708-0467
#
# ----
#
# ##### <<https://bcourses.berkeley.edu/courses/1551896>>
# ##### <<https://braddelong.substack.com/t/quantitative-long-run-global-economic>>
# ##### <<https://braddelong.substack.com/p/quantitative-long-run-global-economic>>
# ##### <<https://substack.com/home/post/p-184363836>>
#
# ----
#
# * Tu 1-3 Evans 560
# * Th 1-3 Zoom
#
# **Course Welcome Email**: <<https://bcourses.berkeley.edu/courses/1551896/discussion_topics/7205916?is_announcement=true>>
#
# And:
#
# Berkeley nbgitpuller: <<https://chromewebstore.google.com/detail/datahub-link-generator/ijbgangngghdanhcnaliiobbiffocahf?hl=en>>
#
# Download DeLong 2025-12-27 current working github repository: <<https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https://github.com/braddelong/working_20251227&urlpath=lab/tree/working_20251227/>>
#
#
#
# <br style="clear: both;">
#
# ---
# ---

# %% [markdown]
# # Econ 196 Seminar: Quantitative Long-Run Global Economic History
#
# <p style="text-align: right;">
#     <img src="images/delong-picture.png"
#      alt="J. Bradford DeLong"
#      width="300"
#      height="300"
#      align="right"
#      style="float:right; margin: 0 0 10px 10px;" />
# </p>
#
# * WEEK 1: Jan 20: Introduction & human population
# * WEEK 2: Jan 27: Productivity levels & technologies
# * WEEK 3: Feb 3: Human evolution, effective population size, & high patriarchy.
# * WEEK 4: Feb 10: Poor agrarian-age Malthusian societies
# * WEEK 5: Feb 17: Societies of domination: land & seaborne agrarian-age empires.
# * Feb 24: —INFLUENZA—
# * WEEK 6: Mar 3: The post-1500 Imperial-Commercial Age
# * Mar 10: Projector down...
# * WEEK 7: Mar 17: 1875 as the Major Hinge of Human History <- **WHERE WE ARE**
# * WEEK 8: Mar 31: The British Industrial Revolution; The Post-1870 Growth Explosion; Reversals of Fortune; quantifying the prosperity hockey stock; 1775-1875 in the "Dover Circle":
# * WEEK 9: Apr 7: The development of underdevelopment
# * WEEK 10: Apr 14: The current spread of wealth across nations, & prospects for further growth acceleration (or deceleration)
# * WEEK 11: Apr 21: Schumpeterian unbalanced growth and political economy; the Fermi paradox: & the future of humanity
# * WEEK 12: Apr 28: Hicks Lecture…
#
# <br style="clear: both;">
#
# ---
# ---

# %% [markdown]
# # The Human Economy
# <p style="text-align: right;">
#     <img src="images/world-population.png"
#      alt="J. Bradford DeLong"
#      width="300"
#      height="300"
#      align="right"
#      style="float:right; margin: 0 0 10px 10px;" /></p>
#
# ### Population
#
# * We have censuses, and guesstimates.
#
# ---
#
# ### Production *per capita*
#
# #### Necessities, conveniences & luxuries, & cultural goods
#
# * Conceptually the question is easy: what multiple/fraction of average income at time X would make you indifferent between living then and living at the average income at time Y?
# * But implementation? Hah!
# * Necessities—we have, not nailed, but under controi
# * Conveniences & luxuries: much harder, as problems of valuation become absurdly difficult.
# * Cultural goods—positive & negative—simply impossible.
# * Inequality & domination...
#
# ---
#
# ### Human technological capability:
#
# * Our ability to manipulate nature and (productively) organize ourselves
# * Grows as the pace of growth of production per capita plus half the pace of growth of population
#     * Why not plus growth rate of population? Assumes workers not productive
#     * Why not just the growth of income per capita? Assumes resources not important
#
# ---
#
# ### Inequality
#
# * Within societies: a big upward leap around the year -3000
#     * Bronze, writing
#     * The horse, the wheel, high patriarchy
#     * & full-fledged societies of domination
#     * Thereafter surprisingly little action, at least not until 1800
#     * Then a rise (“Gilded Age”), fall, and rise again (“Second Gilded Age”)
# * Between societies: post-1800 inequality explosion
#
# <br style="clear: both;">
#
# ---
# ---

# %%
# having done our git-pull: 
#     <https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https://github.com/braddelong/working_20251227&urlpath=lab/tree/working_20251227/>
# and having navigated to and opened the right file:
#    venv/working_20251227/2027-03-10-PLANNED-econ-196-week-7-1875-the-hinge.ipynb
# 
# load libraries

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# declare that there will be a dictionary called "pop", fill in population guesstimates 

pop = {} 
pop[2025] = 8250
pop[2000] = 6170 # relying on <http://ourworldindata.org> <https://ourworldindata.org/population-sources>
pop[1975] = 4070
pop[1950] = 2530
pop[1925] = 2000
pop[1900] = 1650
pop[1875] = 1389
pop[1825] = 1100
pop[1775] = 800
pop[1700] = 610
pop[1600] = 500
pop[1500] = 450
pop[1300] = 430
pop[800] = 200
pop[200] = 260
pop[-600] = 150
pop[-1500] = 91
pop[-3000] = 45
pop[-5000] = 19
pop[-8000] = 5 # <https://www.prb.org/articles/how-many-people-have-ever-lived-on-earth/>
pop[-13000] = 4
pop[-23000] = 3
pop[-48000] = 2
pop[-73000] = 0.01 # <https://en.wikipedia.org/wiki/Prehistoric_demography>

# declare that there will be a dataframe object

human_history_df = pd.DataFrame(
                    list(pop.items()),
                    columns=['year', 'population']
                    )

# add in our guesses as to average real income per capita, which is the
# result of how we organize ourselves coöperatively and manipulate nature 
# to produce true necessities and relatively simple conveniences....
#
# "luxuries" and lifespan not accounted for—economists' hunch is that you
# should multiply the power to produce standard commodities by the "size"
# of the space of commodities that you know how to produce, and then multiply
# that by human lifespan before you have anything that might be a true-ish
# measure of "wealth"...
#
# and as for utility? human flourishing? ha!...

human_history_df.loc[human_history_df["year"] == 2025, "income"] = 18000
human_history_df.loc[human_history_df["year"] == 2000, "income"] = 12000
human_history_df.loc[human_history_df["year"] == 1975, "income"] = 8900
human_history_df.loc[human_history_df["year"] == 1950, "income"] = 5800
human_history_df.loc[human_history_df["year"] == 1925, "income"] = 4400
human_history_df.loc[human_history_df["year"] == 1900, "income"] = 3400
human_history_df.loc[human_history_df["year"] == 1875, "income"] = 2200
human_history_df.loc[human_history_df["year"] == 1825, "income"] = 1800
human_history_df.loc[human_history_df["year"] == 1775, "income"] = 1600
human_history_df.loc[human_history_df["year"] == 1700, "income"] = 1525
human_history_df.loc[human_history_df["year"] == 1600, "income"] = 1450
human_history_df.loc[human_history_df["year"] == 1500, "income"] = 1400
human_history_df.loc[human_history_df["year"] == 1300, 'income'] = 1200
human_history_df.loc[human_history_df["year"] == 800, 'income'] = 1100
human_history_df.loc[human_history_df["year"] == 200, 'income'] = 1100
human_history_df.loc[human_history_df["year"] == -600, 'income'] = 1100
human_history_df.loc[human_history_df["year"] == -1500, 'income'] = 1100
human_history_df.loc[human_history_df["year"] == -3000, 'income'] = 1100
human_history_df.loc[human_history_df["year"] == -5000, 'income'] = 1100
human_history_df.loc[human_history_df["year"] == -8000, 'income'] = 1500
human_history_df.loc[human_history_df["year"] == -13000, 'income'] = 1500
human_history_df.loc[human_history_df["year"] == -23000, 'income'] = 1500
human_history_df.loc[human_history_df["year"] == -48000, 'income'] = 1500
human_history_df.loc[human_history_df["year"] == -73000, 'income'] = 1500

# calculating world product

human_history_df["world_product"] = human_history_df["income"] * human_history_df["population"]

human_history_df.head()
# Out:
#    year  population   income  world_product
# 0  2025      8250.0  18000.0    148500000.0
# 1  2000      6170.0  12000.0     74040000.0
# 2  1975      4070.0   8900.0     36223000.0
# 3  1950      2530.0   5800.0     14674000.0
# 4  1925      2000.0   4400.0      8800000.0

# %%
# time to look at growth rates

import numpy as np

# 1. Make sure there is no index/column ambiguity and you're sorted by year
human_history_df = human_history_df.reset_index(drop=True)
human_history_df = human_history_df.sort_values("year")

# 2. Year gaps
human_history_df["year_diff"] = human_history_df["year"].diff()

# 3. Annual *log* growth rates
human_history_df["pop_growth"] = (
    np.log(human_history_df["population"])
    - np.log(human_history_df["population"].shift(1))
) / human_history_df["year_diff"]

human_history_df["income_growth"] = (
    np.log(human_history_df["income"])
    - np.log(human_history_df["income"].shift(1))
) / human_history_df["year_diff"]

# calculating "technology"—growth rate equal to income growth plus half of population growth

human_history_df["tech_growth"] = (
    human_history_df["income_growth"] + 0.5 * human_history_df["pop_growth"]
)

human_history_df.head()
# Out:
#      year  population  income  world_product  year_diff  pop_growth  \
# 23 -73000        0.01  1500.0           15.0        NaN         NaN
# 22 -48000        2.00  1500.0         3000.0    25000.0    0.000212
# 21 -23000        3.00  1500.0         4500.0    25000.0    0.000016
# 20 -13000        4.00  1500.0         6000.0    10000.0    0.000029
# 19  -8000        5.00  1500.0         7500.0     5000.0    0.000045
#
#     income_growth  tech_growth
# 23            NaN          NaN
# 22            0.0     0.000106
# 21            0.0     0.000008
# 20            0.0     0.000014
# 19            0.0     0.000022

# %%
#constructing a log-level index for "technology"

human_history_df = human_history_df.sort_values("year").reset_index(drop=True)

human_history_df["ln_tech"] = np.nan

human_history_df.loc[human_history_df["year"] == -73000, "ln_tech"] = 0.0

# build ln_tech forward from the first non-NaN
base_idx = human_history_df["ln_tech"].first_valid_index()
mask_after_base = human_history_df.index > base_idx

human_history_df.loc[mask_after_base, "ln_tech"] = (
    human_history_df.loc[mask_after_base, "tech_growth"]
    * human_history_df.loc[mask_after_base, "year_diff"]
).cumsum()

human_history_df.head()

# exponentiate to get a tech index (base = 1 at year 1875)

human_history_df["tech_index"] = np.exp(human_history_df["ln_tech"])

# find the tech_index value at 1875
base_value_1875 = human_history_df.loc[human_history_df["year"] == 1875, "tech_index"].iloc[0]

# rescale the entire index so that tech_index(1875) = 1
human_history_df["tech_index"] = human_history_df["tech_index"] / base_value_1875

human_history_df.head()
# Out:
#     year  population  income  world_product  year_diff  pop_growth  \
# 0 -73000        0.01  1500.0           15.0        NaN         NaN
# 1 -48000        2.00  1500.0         3000.0    25000.0    0.000212
# 2 -23000        3.00  1500.0         4500.0    25000.0    0.000016
# 3 -13000        4.00  1500.0         6000.0    10000.0    0.000029
# 4  -8000        5.00  1500.0         7500.0     5000.0    0.000045
#
#    income_growth  tech_growth   ln_tech  tech_index
# 0            NaN          NaN  0.000000    0.001829
# 1            0.0     0.000106  2.649159    0.025872
# 2            0.0     0.000008  2.851891    0.031687
# 3            0.0     0.000014  2.995732    0.036589
# 4            0.0     0.000022  3.107304    0.040907

# %%
import numpy as np
import matplotlib.pyplot as plt

# Make sure rows are ordered
human_history_df = human_history_df.sort_values("year").reset_index(drop=True)

# Create log-level variables (drop nonpositive values to avoid -inf)
for col in ["population", "income", "tech_index"]:
    human_history_df[f"ln_{col}"] = np.where(
        human_history_df[col] > 0,
        np.log(human_history_df[col]),
        np.nan
    )

fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# 1. Log levels, -13000 to 2025
mask_long = (human_history_df["year"] >= -13000) & (human_history_df["year"] <= 2025)
human_history_df.loc[mask_long].plot(
    x="year",
    y=["ln_population", "ln_income", "ln_tech_index"],
    kind="line",
    ax=axes[0, 0],
    legend=True
)
axes[0, 0].set_title("Log Levels: Population, Income, Technology (-13000–2025)")
axes[0, 0].set_xlabel("Year")
axes[0, 0].set_ylabel("Log level")

# 2. Log levels, 1500 to 2025
mask_mod = (human_history_df["year"] >= 1500) & (human_history_df["year"] <= 2025)
human_history_df.loc[mask_mod].plot(
    x="year",
    y=["ln_population", "ln_income", "ln_tech_index"],
    kind="line",
    ax=axes[0, 1],
    legend=False
)
axes[0, 1].set_title("Log Levels: Population, Income, Technology (1500–2025)")
axes[0, 1].set_xlabel("Year")
axes[0, 1].set_ylabel("Log level")

# 3. Growth rates, -13000 to 2025
human_history_df.loc[mask_long].plot(
    x="year",
    y=["pop_growth", "income_growth", "tech_growth"],
    kind="line",
    ax=axes[1, 0],
    legend=False
)
axes[1, 0].set_title("Annual Growth Rates (-13000–2025)")
axes[1, 0].set_xlabel("Year")
axes[1, 0].set_ylabel("Annual proportional growth rate")
axes[1, 0].set_ylim(bottom=0)

# 4. Growth rates, 1500 to 2025
human_history_df.loc[mask_mod].plot(
    x="year",
    y=["pop_growth", "income_growth", "tech_growth"],
    kind="line",
    ax=axes[1, 1],
    legend=False
)
axes[1, 1].set_title("Annual Growth Rates (1500–2025)")
axes[1, 1].set_xlabel("Year")
axes[1, 1].set_ylabel("Annual proportional growth rate")
axes[1, 1].set_ylim(bottom=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Modeling Rates of Technological Progress
#
# It was, I think, in 1985 back when I was still a graduate student that I really became aware of the "two heads are better than one" argument as I watched Paul Romer present a piece of his dissertation—a piece that had already been accepted by and was about to be published in the _Journal of Political Economy_.
#
# * Romer, Paul M. 1986. “Increasing Returns & Long-Run Growth.” _Journal of Political Economy_ 94(5): 1002–37. <<https://paulromer.net/speeding-up-and-missed-opportunities-evidence/IncreasingReturns.pdf>>.
# * Kremer, Michael. 1993. “Population Growth & Technological Change: One Million B.C. to 1990.” _Quarterly Journal of Economics_ 108 (3): 681–716. <<https://faculty.econ.ucdavis.edu/faculty/gclark/210a/readings/kremer1993.pdf>>>
# * Diamond, Jared. 1997. _Guns, Germs, and Steel: The Fates of Human Societies_. New York: W. W. Norton. <<https://dn721503.ca.archive.org/0/items/fp_Jared_Diamond-Guns_Germs_and_Steel/Jared_Diamond-Guns_Germs_and_Steel.pdf>>.
#
# Paul did something that, in retrospect, is stunningly simple: it took the old production function, pulled ideas out of the undifferentiated capital aggregate, and insisted that they were different—non-rival, accumulating, and capable of generating increasing returns at the social level even when private firms still faced diminishing returns.
#
# Once you see that, you cannot unsee it. Non-rivalry means that if I have the blueprint for the Watt steam engine or for CRISPR, my using it does not prevent you from using it as well. We can both plug the same idea into our production lines, and the marginal cost of your adoption is, essentially, zero. A world made up only of rival goods—land, raw labor, iron ore—grinds against diminishing returns and the Malthusian devil. Add a stock of non-rival ideas that can be copied and recombined, and suddenly the growth rate of knowledge, ￼, can be written, in the simplest possible reduced form, as proportional to the number of brains available to think: ￼.
#
# That is where Michael Kremer enters, walking onstage from the long run of one million B.C. to 1990. Kremer basically says: take Romer’s “two heads are better than one” literally and push it back nearly to Homo erectus with a sharp stick. If ideas are non-rival, more people mean more potential inventors. Combine that with a Malthusian world in which population is limited by technology, and you get the striking empirical regularity Kremer documents: for most of human history, the growth rate of population is roughly proportional to the level of population. More people → more ideas → higher carrying capacity → more people. A feedback loop, not a steady state.
#
# Jared Diamond gives us the spatial counterpart to this temporal story. Geography, crops, domesticable animals, and continental axes determine where dense populations, cities, and written traditions can form. Those are precisely the institutions that let a society store, copy, and recombine non-rival ideas at scale. An Andean herder and a Fertile Crescent scribe are not different in cognitive capacity; what is different is how many other heads their ideas can bump up against, how many previous ideas they can draw on, and how cheaply those ideas can be transmitted.
#
# Put Romer, Kremer, and Diamond together and you get a macrostructure of human history that looks very much like the hockey-stick plots in your notebook: for millennia, population, globa income, and a very crude tech index creep upward as the non-rival idea engine runs slowly in small, partially isolated populations; then the commercial-imperial and industrial eras abruptly knit those populations into a single “anthology intelligence” with vastly expanded means of R&D, and the growth rate of technology jumps by an order of magnitude or more—and keeps on growing.
#
# The true scarce resource in the long run is not stuff; rather, it has been arrangements—non-rival patterns of information and organization that let us get more out of the same rival inputs. History’s hinge points are the moments when we change how many heads can share how many ideas how fast.
#
# All that suggests a very simple model of technological change as a function of world population:
#
# $$
# \begin{equation}
# \frac{\dot H_t}{H_t} =  \alpha P_t^\sigma
# \end{equation}
# $$
#
# Where H is our index of technology—human ideas—and P our estimate of population, and alpha and sigma are parameters to be estimated...
#
# Now you can immediately start complicating this "two heads are better than one" story further. But let's roll with this:

# %%
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit

# Sample: choose the years you want
mask = (human_history_df["year"] >= -13000) & (human_history_df["year"] <= 200)
df_est = human_history_df.loc[mask, ["population", "tech_growth"]].dropna()

P = df_est["population"].values
g = df_est["tech_growth"].values

# Nonlinear model: g = alpha * P**sigma
def g_model(P, alpha, sigma):
    return alpha * (P ** sigma)

# Initial guesses (you can tweak)
alpha0 = 1e-5
sigma0 = 0.5

# Nonlinear least squares
params, cov = curve_fit(g_model, P, g, p0=[alpha0, sigma0])
alpha_hat, sigma_hat = params

print("Estimated alpha:", alpha_hat)
print("Estimated sigma:", sigma_hat)

import numpy as np
from scipy.optimize import curve_fit

# Your model and data
def g_model(P, alpha, sigma):
    return alpha * (P ** sigma)

P = df_est["population"].values
g = df_est["tech_growth"].values

# Fit
params, cov = curve_fit(g_model, P, g, p0=[1e-5, 0.5])
alpha_hat, sigma_hat = params

# Standard errors from covariance matrix
se = np.sqrt(np.diag(cov))
se_alpha, se_sigma = se

# Fitted values and residuals
g_hat = g_model(P, alpha_hat, sigma_hat)
resid = g - g_hat

# Simple R^2
ss_res = np.sum(resid**2)
ss_tot = np.sum((g - np.mean(g))**2)
r2 = 1 - ss_res / ss_tot

# t‑statistics
t_alpha = alpha_hat / se_alpha
t_sigma = sigma_hat / se_sigma

print("Nonlinear least squares with curve_fit")
print("--------------------------------------")
print(f"alpha_hat = {alpha_hat:.6g}  (se = {se_alpha:.6g},  t = {t_alpha:.3f})")
print(f"sigma_hat = {sigma_hat:.6g}  (se = {se_sigma:.6g},  t = {t_sigma:.3f})")
print()
print(f"Residual sum of squares (SSR): {ss_res:.6g}")
print(f"Total sum of squares (SST):    {ss_tot:.6g}")
print(f"R-squared:                     {r2:.4f}")
print(f"Number of observations:        {len(P)}")
# Out:
# Estimated alpha: 2.9724689767404176e-05
# Estimated sigma: 0.4485637275070824
# Nonlinear least squares with curve_fit
# --------------------------------------
# alpha_hat = 2.97247e-05  (se = 1.10888e-05,  t = 2.681)
# sigma_hat = 0.448564  (se = 0.075091,  t = 5.974)
#
# Residual sum of squares (SSR): 6.29094e-09
# Total sum of squares (SST):    9.64693e-08
# R-squared:                     0.9348
# Number of observations:        7

# %%
# 1. Build a forecast df with years and population up to 2025
year_min, year_max = -13000, 2025

df_forecast = (
    human_history_df
    .loc[(human_history_df["year"] >= year_min) & (human_history_df["year"] <= year_max),
         ["year", "population", "tech_index", "tech_growth"]]
    .sort_values("year")
    .copy()
)

# 2. Use your estimated parameters to get fitted growth g_hat for ALL those years
def g_model(P, alpha, sigma):
    return alpha * (P ** sigma)

df_forecast["g_hat"] = g_model(df_forecast["population"].values,
                               alpha_hat, sigma_hat)

# Check: g_hat is now defined from -13000 through 2025 (given population data)

# %%
# Choose anchor year for level normalization
anchor_year = 200

# Make sure we have that year in the forecast df
assert (df_forecast["year"] == anchor_year).any(), "Anchor year missing!"

# Sort by year for cumulation
df_forecast = df_forecast.sort_values("year").reset_index(drop=True)

# Get anchor index and observed tech level there
i0 = df_forecast.index[df_forecast["year"] == anchor_year][0]
H0 = df_forecast.loc[i0, "tech_index"]

# Initialize fitted tech index
H_fit = np.zeros(len(df_forecast))
H_fit[i0] = H0

# Cumulate FORWARD from anchor_year to 2025
for i in range(i0 + 1, len(df_forecast)):
    g_t = df_forecast.loc[i, "g_hat"]  # growth rate between year-1 and year
    H_fit[i] = H_fit[i - 1] * np.exp(g_t)  # Δt = 1

# Optionally, cumulate BACKWARD before anchor_year
for i in range(i0 - 1, -1, -1):
    g_tplus1 = df_forecast.loc[i + 1, "g_hat"]  # growth from year_i to year_{i+1}
    H_fit[i] = H_fit[i + 1] / np.exp(g_tplus1)

df_forecast["H_hat"] = H_fit

# %%
import numpy as np
import matplotlib.pyplot as plt

# Restrict window
mask = (df_forecast["year"] >= -13000) & (df_forecast["year"] <= 200)
df_plot = df_forecast.loc[mask].copy()

years = df_plot["year"].values
P     = df_plot["population"].values

H_act = df_plot["tech_index"].values      # actual level
H_fit = df_plot["H_hat"].values          # fitted level

g_act = df_plot["tech_growth"].values    # actual growth (may have NaNs)
g_fit = df_plot["g_hat"].values          # fitted growth

# We'll work in logs for levels; drop non‑positive
mask_pos = (H_act > 0) & (H_fit > 0)
years_L = years[mask_pos]
P_L     = P[mask_pos]
logH_a  = np.log(H_act[mask_pos])
logH_f  = np.log(H_fit[mask_pos])

fig, axes = plt.subplots(2, 2, figsize=(14, 9))

# (1,1) Log tech level vs population: actual + fitted
ax = axes[0, 0]
ax.scatter(P_L, logH_a, color="tab:blue", alpha=0.8,
           label="log tech_index (actual)")
# sort for clean fitted curve
order_P_L = np.argsort(P_L)
ax.plot(P_L[order_P_L], logH_f[order_P_L],
        color="tab:orange", linestyle="-",
        label="log tech_index (fitted)")
ax.set_xlabel("Population")
ax.set_ylabel("log technology level")
ax.set_title("Log Tech Level vs Population (-13000 to 200)")
ax.grid(True, alpha=0.3)
ax.legend()

# (1,2) Log tech level vs year: actual + fitted
ax = axes[0, 1]
ax.plot(years_L, logH_a, "o", color="tab:blue",
        label="log tech_index (actual)")
order_year_L = np.argsort(years_L)
ax.plot(years_L[order_year_L], logH_f[order_year_L],
        "-", color="tab:orange",
        label="log tech_index (fitted)")
ax.set_xlabel("Year")
ax.set_ylabel("log technology level")
ax.set_title("Log Tech Level vs Year (-13000 to 200)")
ax.grid(True, alpha=0.3)
ax.legend()

# (2,1) Tech growth vs population: actual + fitted
ax = axes[1, 0]
mask_g_act = ~np.isnan(g_act)
ax.scatter(P[mask_g_act], g_act[mask_g_act],
           color="tab:blue", alpha=0.8,
           label="tech_growth (actual)")
order_P = np.argsort(P)
ax.plot(P[order_P], g_fit[order_P],
        color="tab:orange", linestyle="-",
        label="tech_growth (fitted)")
ax.set_xlabel("Population")
ax.set_ylabel("Tech growth rate")
ax.set_title("Tech Growth vs Population (-13000 to 200)")
ax.grid(True, alpha=0.3)
ax.legend()

# (2,2) Tech growth vs year: actual + fitted
ax = axes[1, 1]
ax.scatter(years[mask_g_act], g_act[mask_g_act],
           color="tab:blue", alpha=0.8,
           label="tech_growth (actual)")
order_year = np.argsort(years)
ax.plot(years[order_year], g_fit[order_year],
        color="tab:orange", linestyle="-",
        label="tech_growth (fitted)")
ax.set_xlabel("Year")
ax.set_ylabel("Tech growth rate")
ax.set_title("Tech Growth vs Year (-13000 to 200)")
ax.grid(True, alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Restrict to desired window
mask = (df_forecast["year"] >= -3000) & (df_forecast["year"] <= 2025)
df_plot = df_forecast.loc[mask].copy()

# Avoid log of non‑positive values
df_plot = df_plot[df_plot["tech_index"] > 0]
df_plot = df_plot[df_plot["H_hat"] > 0]

years = df_plot["year"].values
log_H_actual = np.log(df_plot["tech_index"].values)
log_H_fit    = np.log(df_plot["H_hat"].values)

g_actual = df_plot["tech_growth"].values
g_fit    = df_plot["g_hat"].values

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# ---- (1) Log tech index: actual vs fitted ----
ax = axes[0]
ax.plot(years, log_H_actual, "o-", color="tab:blue", label="log tech_index (actual)")
ax.plot(years, log_H_fit, "-",  color="tab:orange", label="log tech_index (fitted)")
ax.set_xlabel("Year")
ax.set_ylabel("log technology index")
ax.set_title("Log Technology Index: Actual vs Fitted")
ax.grid(True, alpha=0.3)
ax.legend()

# ---- (2) Tech growth rate: actual vs fitted ----
ax = axes[1]
# only plot actual where it exists
mask_actual_g = ~np.isnan(g_actual)
ax.plot(years[mask_actual_g], g_actual[mask_actual_g],
        "o", color="tab:blue", label="tech_growth (actual)")
ax.plot(years, g_fit, "-", color="tab:orange", label="tech_growth (fitted)")
ax.set_xlabel("Year")
ax.set_ylabel("Tech growth rate")
ax.set_title("Tech Growth Rate: Actual vs Fitted")
ax.grid(True, alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# --- 1. Simulation series (already built from -3000 onward) ---

year_arr = np.array(year)
P_arr    = np.array(P)
y_arr    = np.array(y)
H_arr    = np.array(H)
h_arr    = np.array(h)

# Restrict simulation to -3000 .. 200
mask_sim = (year_arr >= -3000) & (year_arr <= 200)
year_sim = year_arr[mask_sim]
P_sim    = P_arr[mask_sim]
y_sim    = y_arr[mask_sim]
H_sim    = H_arr[mask_sim]
h_sim    = h_arr[mask_sim]

# --- 2. Historical data over -3000 .. 200 ---

df = human_history_df.copy()
df["year"] = df["year"].astype(int)

mask_data = (df["year"] >= -3000) & (df["year"] <= 200)
df_sub = df.loc[mask_data].sort_values("year")

year_data  = df_sub["year"].values
pop_data   = df_sub["population"].values
inc_data   = df_sub["income"].values
tech_data  = df_sub["tech_index"].values
gtech_data = df_sub["tech_growth"].values

# --- 3. Logs for positive levels only ---

def safe_log(x):
    x = np.array(x, dtype=float)
    x[x <= 0] = np.nan
    return np.log(x)

lnP_sim   = safe_log(P_sim)
lny_sim   = safe_log(y_sim)
lnH_sim   = safe_log(H_sim)

lnP_data  = safe_log(pop_data)
lny_data  = safe_log(inc_data)
lnH_data  = safe_log(tech_data)

# --- 4. 2×2 plots: actual (data) vs fitted (simulation) ---

fig, axes = plt.subplots(2, 2, figsize=(14, 8))

# (1,1) Log population: data vs fitted
ax = axes[0, 0]
ax.plot(year_sim, lnP_sim, color="tab:blue", label="ln P (fitted)")
ax.plot(year_data, lnP_data, color="tab:orange", marker="o",
        linestyle="-", label="ln population (actual)")
ax.set_xlabel("Year")
ax.set_ylabel("Log population")
ax.set_title("Log Population: Actual vs Fitted (-3000 to 200)")
ax.grid(True, alpha=0.3)
ax.legend()

# (1,2) Log income: data vs fitted
ax = axes[0, 1]
ax.plot(year_sim, lny_sim, color="tab:blue", label="ln y (fitted)")
ax.plot(year_data, lny_data, color="tab:orange", marker="o",
        linestyle="-", label="ln income (actual)")
ax.set_xlabel("Year")
ax.set_ylabel("Log income / productivity")
ax.set_title("Log Income: Actual vs Fitted (-3000 to 200)")
ax.grid(True, alpha=0.3)
ax.legend()

# (2,1) Log tech level: data vs fitted
ax = axes[1, 0]
ax.plot(year_sim, lnH_sim, color="tab:blue", label="ln H (fitted)")
ax.plot(year_data, lnH_data, color="tab:orange", marker="o",
        linestyle="-", label="ln tech_level (actual)")
ax.set_xlabel("Year")
ax.set_ylabel("Log technology level")
ax.set_title("Log Tech Level: Actual vs Fitted (-3000 to 200)")
ax.grid(True, alpha=0.3)
ax.legend()

# (2,2) Tech growth rate: data vs fitted (levels, not logs)
ax = axes[1, 1]
ax.plot(year_sim, h_sim, color="tab:blue", label="h (fitted)")
ax.plot(year_data, gtech_data, color="tab:orange", marker="o",
        linestyle="-", label="tech_growth (actual)")
ax.set_xlabel("Year")
ax.set_ylabel("Tech growth rate")
ax.set_title("Tech Growth: Actual vs Fitted (-3000 to 200)")
ax.grid(True, alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# --- 1. Estimate g = alpha * P on years -3000 to 1500 (no intercept) ---

mask_est = (human_history_df["year"] >= -3000) & (human_history_df["year"] <= 1500)
df_est = human_history_df.loc[mask_est, ["year", "population", "tech_growth"]].copy()
df_est = df_est.dropna(subset=["population", "tech_growth"])

X = df_est[["population"]]      # no constant: g = alpha * P
y = df_est["tech_growth"]

model = sm.OLS(y, X)
results = model.fit()

alpha_hat = results.params["population"]
print("Estimated alpha:", alpha_hat)

# Fitted values for estimation sample (for plotting)
df_est["g_hat"] = alpha_hat * df_est["population"]

# --- 2. Build forecast dataset up to 1775 and compute fitted growth ---

mask_forecast = (human_history_df["year"] >= -3000) & (human_history_df["year"] <= 1775)
df_forecast = human_history_df.loc[mask_forecast, ["year", "population", "tech_growth"]].copy()
df_forecast = df_forecast.dropna(subset=["population"])
df_forecast = df_forecast.sort_values("year").reset_index(drop=True)

df_forecast["g_hat"] = alpha_hat * df_forecast["population"]

years     = df_forecast["year"].values
P_fore    = df_forecast["population"].values
g_actual  = df_forecast["tech_growth"].values
g_fitted  = df_forecast["g_hat"].values

# --- 3. Construct cumulative tech levels (actual and fitted) ---

A_actual = np.full_like(g_fitted, np.nan, dtype=float)
A_fitted = np.full_like(g_fitted, np.nan, dtype=float)

# normalize fitted at first observation
A_fitted[0] = 1.0
# if we have an actual growth rate at the first observation, normalize that too
if not np.isnan(g_actual[0]):
    A_actual[0] = 1.0

for i in range(1, len(years)):
    dt = years[i] - years[i - 1]

    # fitted tech path always uses fitted growth
    A_fitted[i] = A_fitted[i - 1] * np.exp(g_fitted[i] * dt)

    # actual tech path where we have an observed growth rate
    if not np.isnan(g_actual[i]):
        if np.isnan(A_actual[i - 1]):
            # if actual path was not yet initialized, anchor it to the fitted level
            A_actual[i - 1] = A_fitted[i - 1]
        A_actual[i] = A_actual[i - 1] * np.exp(g_actual[i] * dt)

df_forecast["A_fitted"] = A_fitted
df_forecast["A_actual"] = A_actual

# --- 4. 2×2 plots: growth & levels vs population and vs year ---

fig, axes = plt.subplots(2, 2, figsize=(14, 8))

# (1,1) Growth vs population (actual + fitted), up to 1775
ax = axes[0, 0]
mask_actual = df_forecast["tech_growth"].notna()

ax.scatter(
    df_forecast.loc[mask_actual, "population"],
    df_forecast.loc[mask_actual, "tech_growth"],
    color="tab:blue",
    label="Actual tech_growth"
)

df_fore_sorted = df_forecast.sort_values("population")
ax.plot(
    df_fore_sorted["population"],
    df_fore_sorted["g_hat"],
    color="tab:orange",
    linestyle="-",
    label="Fitted tech_growth (g_hat)"
)

ax.set_xlabel("Population (millions)")
ax.set_ylabel("Annual tech growth (g)")
ax.set_title("Tech Growth vs Population (to 1775)")
ax.grid(True, alpha=0.3)
ax.legend()

# (1,2) Growth vs year (actual + fitted), up to 1775
ax = axes[0, 1]
ax.plot(
    df_forecast["year"],
    df_forecast["g_hat"],
    color="tab:orange",
    linestyle="-",
    label="Fitted tech_growth (g_hat)"
)

ax.plot(
    df_forecast.loc[mask_actual, "year"],
    df_forecast.loc[mask_actual, "tech_growth"],
    color="tab:blue",
    linestyle="--",
    marker="o",
    label="Actual tech_growth"
)

ax.set_xlabel("Year")
ax.set_ylabel("Annual tech growth (g)")
ax.set_title("Tech Growth vs Year (to 1775)")
ax.grid(True, alpha=0.3)
ax.legend()

# (2,1) Cumulative tech level vs population (actual + fitted), to 1775
ax = axes[1, 0]
mask_A_actual = df_forecast["A_actual"].notna()

ax.plot(
    df_forecast["population"],
    df_forecast["A_fitted"],
    color="tab:orange",
    linestyle="-",
    label="Fitted tech level"
)

ax.plot(
    df_forecast.loc[mask_A_actual, "population"],
    df_forecast.loc[mask_A_actual, "A_actual"],
    color="tab:blue",
    linestyle="--",
    marker="o",
    label="Actual tech level (where observed)"
)

ax.set_xlabel("Population (millions)")
ax.set_ylabel("Tech level (index, normalized at first year)")
ax.set_title("Tech Level vs Population (to 1775)")
ax.grid(True, alpha=0.3)
ax.legend()

# (2,2) Cumulative tech level vs year (actual + fitted), to 1775
ax = axes[1, 1]
ax.plot(
    df_forecast["year"],
    df_forecast["A_fitted"],
    color="tab:orange",
    linestyle="-",
    label="Fitted tech level"
)

ax.plot(
    df_forecast.loc[mask_A_actual, "year"],
    df_forecast.loc[mask_A_actual, "A_actual"],
    color="tab:blue",
    linestyle="--",
    marker="o",
    label="Actual tech level (where observed)"
)

ax.set_xlabel("Year")
ax.set_ylabel("Tech level (index, normalized at first year)")
ax.set_title("Tech Level vs Year (to 1775)")
ax.grid(True, alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# Optionally, print the regression summary as well:
print(results.summary())

print("Estimated alpha:", alpha_hat)

# %%
# %matplotlib inline

import numpy as np               # math package
import matplotlib.pyplot as plt  # plotting package
import random as rnd             # random number package

alpha = 0.000002                # two-heads-are-better-than-one coefficient
g = []                           # time-series list for productivity growth
n = []                           # time-series list for population growth
epsilon = []                     # uncorrelated random shocks to population
H = [0.09]                       # time-series list for tech level, and initial tech level in year -3000
P = [45]                         # time-series list for population & labor force level, and initial population level in year -3000
y = [1100]                       # time-series list for productivity & living standard level, and initial level in year -3000
h = [0.00000175 * P[0]]          # time-series list for rate of technology increase, and initial value in year -3000
year = [-3000]                   # time-series list for year

gamma = 2                        # salience of ideas vis-à-vis resources in determining productivity
beta = 0.025                     # annual response of population growth to relative living standards

for t in range(4775):                                   # loop through human history from the year -3000 to 1775
    epsilon = epsilon + [rnd.normalvariate(0, 0.01)]           # calculate this year's population shock
    n = n + [beta * (y[t] - 1000)/1000 + epsilon[t]]           # calculate this year's population growth rate
    g = g + [h[t] - n[t]/gamma + rnd.normalvariate(0, 0.0002)] # calculate this year's productivity change
    h = h + [alpha * P[t]]                                     # calculate this year's technology change
    y = y + [y[t]*np.exp(g[t])]                                # calculate this year's productivity level
    P = P + [P[t]*np.exp(n[t])]                                # calculate this year's population level
    H = H + [H[t]*np.exp(h[t])]                                # calculate this year's technology level
    year = year + [t - 2999]                                   # increment year

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulation series
year_arr = np.array(year)
P_arr    = np.array(P)
y_arr    = np.array(y)
H_arr    = np.array(H)
h_arr    = np.array(h)

# Historical data restricted to [-5000, 2025]
df = human_history_df.copy()
df["year"] = df["year"].astype(int)
mask   = (df["year"] >= -5000) & (df["year"] <= 2025)
df_sub = df.loc[mask].copy()

years_df = df_sub["year"].values
pop_df   = df_sub["population"].values
inc_df   = df_sub["income"].values
tech_df  = df_sub["tech_index"].values
gtech_df = df_sub["tech_growth"].values

# Log transforms for positive levels only
# (we drop or mask nonpositive values to avoid -inf)
def safe_log(x):
    x = np.array(x, dtype=float)
    x[x <= 0] = np.nan
    return np.log(x)

lnP_sim   = safe_log(P_arr)
lny_sim   = safe_log(y_arr)
lnH_sim   = safe_log(H_arr)

lnP_data  = safe_log(pop_df)
lny_data  = safe_log(inc_df)
lnH_data  = safe_log(tech_df)

fig, axes = plt.subplots(2, 2, figsize=(14, 8))

# (1,1) log P and log population vs year
ax = axes[0, 0]
ax.plot(year_arr, lnP_sim, color="tab:blue", label="ln P (simulated)")
ax.plot(years_df, lnP_data, color="tab:orange", marker="o",
        linestyle="-", label="ln population (historical)")
ax.set_xlabel("Year")
ax.set_ylabel("Log population")
ax.set_title("Log P vs log population (≥ -3000)")
ax.grid(True, alpha=0.3)
ax.legend()

# (1,2) log y and log income vs year
ax = axes[0, 1]
ax.plot(year_arr, lny_sim, color="tab:blue", label="ln y (simulated)")
ax.plot(years_df, lny_data, color="tab:orange", marker="o",
        linestyle="-", label="ln income (historical)")
ax.set_xlabel("Year")
ax.set_ylabel("Log income / productivity")
ax.set_title("Log y vs log income (≥ -3000)")
ax.grid(True, alpha=0.3)
ax.legend()

# (2,1) log H and log tech_level vs year
ax = axes[1, 0]
ax.plot(year_arr, lnH_sim, color="tab:blue", label="ln H (simulated)")
ax.plot(years_df, lnH_data, color="tab:orange", marker="o",
        linestyle="-", label="ln tech_level (historical)")
ax.set_xlabel("Year")
ax.set_ylabel("Log technology level")
ax.set_title("Log H vs log tech_level (≥ -3000)")
ax.grid(True, alpha=0.3)
ax.legend()

# (2,2) h and tech_growth vs year (kept in levels: growth rates)
ax = axes[1, 1]
ax.plot(year_arr, h_arr, color="tab:blue", label="h (simulated)")
ax.plot(years_df, gtech_df, color="tab:orange", marker="o",
        linestyle="-", label="tech_growth (historical)")
ax.set_xlabel("Year")
ax.set_ylabel("Technology growth")
ax.set_title("h vs tech_growth (≥ -3000)")
ax.grid(True, alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulation series: from -3000 to 2025
year_arr = np.array(year)
P_arr    = np.array(P)
y_arr    = np.array(y)
H_arr    = np.array(H)
h_arr    = np.array(h)

# Historical data
df = human_history_df.copy()
df["year"] = df["year"].astype(int)

# Keep only years within the simulation window [-3000, 2025]
mask = (df["year"] >= -3000) & (df["year"] <= 2025)
df_sub = df.loc[mask].copy()

years_df = df_sub["year"].values
pop_df   = df_sub["population"].values
inc_df   = df_sub["income"].values
tech_df  = df_sub["tech_index"].values   # tech_level
gtech_df = df_sub["tech_growth"].values  # tech_growth

fig, axes = plt.subplots(2, 2, figsize=(14, 8))

# (1,1) P and population vs year
ax = axes[0, 0]
ax.plot(year_arr, P_arr, color="tab:blue", label="P (simulated)")
ax.plot(years_df, pop_df, color="tab:orange", marker="o",
        linestyle="-", label="population (historical)")
ax.set_xlabel("Year")
ax.set_ylabel("Population level")
ax.set_title("P vs population (≥ -3000)")
ax.grid(True, alpha=0.3)
ax.legend()

# (1,2) y and income vs year
ax = axes[0, 1]
ax.plot(year_arr, y_arr, color="tab:blue", label="y (simulated)")
ax.plot(years_df, inc_df, color="tab:orange", marker="o",
        linestyle="-", label="income (historical)")
ax.set_xlabel("Year")
ax.set_ylabel("Income / productivity level")
ax.set_title("y vs income (≥ -3000)")
ax.grid(True, alpha=0.3)
ax.legend()

# (2,1) H and tech_level vs year
ax = axes[1, 0]
ax.plot(year_arr, H_arr, color="tab:blue", label="H (simulated)")
ax.plot(years_df, tech_df, color="tab:orange", marker="o",
        linestyle="-", label="tech_level (historical)")
ax.set_xlabel("Year")
ax.set_ylabel("Technology level")
ax.set_title("H vs tech_level (≥ -3000)")
ax.grid(True, alpha=0.3)
ax.legend()

# (2,2) h and tech_growth vs year
ax = axes[1, 1]
ax.plot(year_arr, h_arr, color="tab:blue", label="h (simulated)")
ax.plot(years_df, gtech_df, color="tab:orange", marker="o",
        linestyle="-", label="tech_growth (historical)")
ax.set_xlabel("Year")
ax.set_ylabel("Technology growth")
ax.set_title("h vs tech_growth (≥ -3000)")
ax.grid(True, alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# %%
human_history_df

# %% [markdown]
# And we want to do so. So let us immediately introduce a stepping-on-toes effect: while two heads are better than one, but not twice as good as one. Let there be a parameter σ, we initially set σ = 0.5, the square-root: two heads are 1.414 times as good as one:
#
# $$
# \begin{equation}
# \frac{\dot H_t}{H_t} =  \alpha_t P_t^{\sigma}
# \end{equation}
# $$
#
# Let's roll with this thus:

# %%
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit

# Sample: choose the years you want
mask = (human_history_df["year"] >= -3000) & (human_history_df["year"] <= 1500)
df_est = human_history_df.loc[mask, ["population", "tech_growth"]].dropna()

P = df_est["population"].values
g = df_est["tech_growth"].values

# Nonlinear model: g = alpha * P**sigma
def g_model(P, alpha, sigma):
    return alpha * (P ** sigma)

# Initial guesses (you can tweak)
alpha0 = 1e-5
sigma0 = 0.5

# Nonlinear least squares
params, cov = curve_fit(g_model, P, g, p0=[alpha0, sigma0])
alpha_hat, sigma_hat = params

print("Estimated alpha:", alpha_hat)
print("Estimated sigma:", sigma_hat)

# Fitted values for plotting or further use
g_hat = g_model(P, alpha_hat, sigma_hat)
df_est["g_hat"] = g_hat

# %%
import numpy as np
import statsmodels.api as sm

# 1. Restrict sample
mask = (human_history_df["year"] >= -3000) & (human_history_df["year"] <= 1500)
df_est = human_history_df.loc[mask, ["year", "population", "tech_growth"]].copy()
df_est = df_est.dropna(subset=["population", "tech_growth"])

# 2. Build logs (drop nonpositive tech_growth if any)
df_est = df_est[df_est["tech_growth"] > 0].copy()
df_est["ln_gA"] = np.log(df_est["tech_growth"])
df_est["ln_N"]  = np.log(df_est["population"])

# 3. OLS: ln_gA = ln(alpha) + sigma * ln_N + error
X = sm.add_constant(df_est[["ln_N"]])  # constant = ln(alpha)
y = df_est["ln_gA"]

model   = sm.OLS(y, X)
results = model.fit()
print(results.summary())

# 4. Recover parameters
alpha_hat = np.exp(results.params["const"])
sigma_hat = results.params["ln_N"]

print("Estimated alpha:", alpha_hat)
print("Estimated sigma:", sigma_hat)

# now plot what we are interested in: the fit

import matplotlib.pyplot as plt

# Make sure we have fitted values
df_est["ln_gA_hat"] = results.fittedvalues
df_est["gA_hat"] = np.exp(df_est["ln_gA_hat"])

fig, ax = plt.subplots(figsize=(8, 6))

# Actual tech growth vs population
ax.scatter(
    df_est["population"],
    df_est["tech_growth"],
    color="tab:blue",
    label="Actual tech_growth"
)

# Fitted tech growth vs population
ax.plot(
    df_est["population"].sort_values(),
    df_est.set_index("population").loc[df_est["population"].sort_values(), "gA_hat"],
    color="tab:orange",
    linestyle="-",
    marker="o",
    label="Fitted tech_growth (gA_hat)"
)

ax.set_xlabel("Population (millions)")
ax.set_ylabel("Annual log tech growth (tech_growth)")
ax.set_title("Tech Growth vs Population\nActual and Fitted from log–linear regression")
ax.grid(True, alpha=0.3)
ax.legend()
ax.set_ylim(bottom=-0.0003)


plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

# --- 1. Restrict sample and estimate log–linear model as before ---

mask = (human_history_df["year"] >= -3000) & (human_history_df["year"] <= 1500)
df_est = human_history_df.loc[mask, ["year", "population", "tech_growth"]].copy()
df_est = df_est.dropna(subset=["population", "tech_growth"])

# drop nonpositive tech_growth
df_est = df_est[df_est["tech_growth"] > 0].copy()
df_est["ln_gA"] = np.log(df_est["tech_growth"])
df_est["ln_N"]  = np.log(df_est["population"])

X = sm.add_constant(df_est[["ln_N"]])
y = df_est["ln_gA"]

model   = sm.OLS(y, X)
results = model.fit()

alpha_hat = np.exp(results.params["const"])
sigma_hat = results.params["ln_N"]

df_est["ln_gA_hat"] = results.fittedvalues
df_est["gA_hat"]    = np.exp(df_est["ln_gA_hat"])

# --- 2. Build forecast dataframe (years, tech_growth, gA_hat) up to 1500 ---

df_forecast = human_history_df.loc[
    (human_history_df["year"] >= -3000) & (human_history_df["year"] <= 1500),
    ["year", "tech_growth", "population"]
].copy()

df_forecast = df_forecast.sort_values("year").reset_index(drop=True)

# fill fitted growth using alpha_hat * N^sigma_hat
df_forecast["gA_hat"] = alpha_hat * (df_forecast["population"] ** sigma_hat)

years     = df_forecast["year"].values
gA_actual = df_forecast["tech_growth"].values
gA_fitted = df_forecast["gA_hat"].values

A_actual = np.empty_like(gA_fitted, dtype=float)
A_fitted = np.empty_like(gA_fitted, dtype=float)

A_actual[:] = np.nan
A_fitted[:] = np.nan

# normalize both at first observation to 1
A_fitted[0] = 1.0

if not np.isnan(gA_actual[0]):
    A_actual[0] = 1.0

for i in range(1, len(years)):
    dt = years[i] - years[i - 1]

    # fitted path always uses fitted growth
    A_fitted[i] = A_fitted[i - 1] * np.exp(gA_fitted[i] * dt)

    # actual path where we have actual growth
    if not np.isnan(gA_actual[i]):
        if np.isnan(A_actual[i - 1]):
            A_actual[i - 1] = A_fitted[i - 1]
        A_actual[i] = A_actual[i - 1] * np.exp(gA_actual[i] * dt)

df_forecast["A_actual"] = A_actual
df_forecast["A_fitted"] = A_fitted

# --- 3. 1 x 2 figure: left = growth vs population; right = tech level vs time ---

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Left: tech growth vs population (actual + fitted)
ax1.scatter(
    df_est["population"],
    df_est["tech_growth"],
    color="tab:blue",
    label="Actual tech_growth"
)

# sort by population for a smooth fitted line
df_est_sorted = df_est.sort_values("population")
ax1.plot(
    df_est_sorted["population"],
    df_est_sorted["gA_hat"],
    color="tab:orange",
    linestyle="-",
    marker="o",
    label="Fitted tech_growth (gA_hat)"
)

ax1.set_xlabel("Population (millions)")
ax1.set_ylabel("Annual log tech growth (tech_growth)")
ax1.set_title("Tech Growth vs Population\nActual and Fitted")
ax1.grid(True, alpha=0.3)
ax1.legend()
ax1.set_ylim(bottom=-0.001)


# Right: tech level paths vs time
ax2.plot(
    df_forecast["year"],
    df_forecast["A_fitted"],
    color="tab:orange",
    linestyle="-",
    label="Fitted tech level"
)

ax2.plot(
    df_forecast["year"],
    df_forecast["A_actual"],
    color="tab:blue",
    linestyle="--",
    marker="o",
    label="Actual tech level (where observed)"
)

ax2.set_xlabel("Year")
ax2.set_ylabel("Tech level (index = 1 at first observation)")
ax2.set_title("Tech Level vs Time\nActual and Fitted (to 1500)")
ax2.grid(True, alpha=0.3)
ax2.legend()

plt.tight_layout()
plt.show()

# --- 4. Print regression results and parameter estimates below the plots ---

print(results.summary())
print("\nEstimated alpha:", alpha_hat)
print("Estimated sigma:", sigma_hat)

# %% [markdown]
# We can say that it is doing OK—lagging behind what I politely call the "Late-Antiquity Growth Pause" rather than the "Dark Age", but then by 1500 catching up.
#
# However:

# %%
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# --- 1. Rebuild the estimation sample (same as cell 19) ---

mask_est = (human_history_df["year"] >= -5000) & (human_history_df["year"] <= 200)
df_est = human_history_df.loc[mask_est, ["year", "population", "tech_growth"]].copy()
df_est = df_est.dropna(subset=["population", "tech_growth"])

df_est = df_est[df_est["tech_growth"] > 0].copy()
df_est["ln_gA"] = np.log(df_est["tech_growth"])
df_est["ln_N"]  = np.log(df_est["population"])

X = sm.add_constant(df_est[["ln_N"]])
y = df_est["ln_gA"]

model   = sm.OLS(y, X)
results = model.fit()

alpha_hat = np.exp(results.params["const"])
sigma_hat = results.params["ln_N"]

print(results.summary())
print("Estimated alpha:", alpha_hat)
print("Estimated sigma:", sigma_hat)

# --- 2. Build forecast dataset to year 1875, and compute fitted growth ---

mask_forecast = (human_history_df["year"] >= -5000) & (human_history_df["year"] <= 1875)
df_forecast = human_history_df.loc[mask_forecast, ["year", "population", "tech_growth"]].copy()

df_forecast = df_forecast.dropna(subset=["population"])
df_forecast = df_forecast[df_forecast["population"] > 0].copy()

df_forecast["ln_N"] = np.log(df_forecast["population"])
df_forecast["ln_gA_hat"] = np.log(alpha_hat) + sigma_hat * df_forecast["ln_N"]
df_forecast["gA_hat"] = np.exp(df_forecast["ln_gA_hat"])

# --- 3. Plot 1: tech growth and fitted growth vs population (to 1875) ---

fig, ax = plt.subplots(figsize=(8, 6))

mask_actual = df_forecast["tech_growth"].notna()
ax.scatter(
    df_forecast.loc[mask_actual, "population"],
    df_forecast.loc[mask_actual, "tech_growth"],
    color="tab:blue",
    label="Actual tech_growth"
)

df_sorted_N = df_forecast.sort_values("population")
ax.plot(
    df_sorted_N["population"],
    df_sorted_N["gA_hat"],
    color="tab:orange",
    linestyle="-",
    label="Fitted tech_growth (gA_hat)"
)

ax.set_xlabel("Population (millions)")
ax.set_ylabel("Annual log tech growth")
ax.set_title("Tech Growth vs Population\nActual (in-sample) and Fitted (to year 1875)")
ax.grid(True, alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# --- 4. Construct tech level paths (actual and fitted) up to 1875 ---

df_forecast = df_forecast.sort_values("year").copy()

years    = df_forecast["year"].values
gA_act   = df_forecast["tech_growth"].values
gA_fit   = df_forecast["gA_hat"].values

A_act = np.empty_like(gA_fit, dtype=float)
A_fit = np.empty_like(gA_fit, dtype=float)

A_act[0] = 1.0
A_fit[0] = 1.0

for i in range(1, len(years)):
    dt = years[i] - years[i - 1]

    # fitted tech level: always uses fitted growth
    A_fit[i] = A_fit[i - 1] * np.exp(gA_fit[i] * dt)

    # actual tech level: only where we observe growth
    if not np.isnan(gA_act[i]):
        if np.isnan(A_act[i - 1]):
            A_act[i - 1] = A_fit[i - 1]
        A_act[i] = A_act[i - 1] * np.exp(gA_act[i] * dt)
    else:
        A_act[i] = np.nan

df_forecast["A_actual"] = A_act
df_forecast["A_fitted"] = A_fit

# --- 5. Plot 2: tech level and fitted tech level vs time (to 1875) ---

fig, ax = plt.subplots(figsize=(9, 6))

ax.plot(
    df_forecast["year"],
    df_forecast["A_fitted"],
    color="tab:orange",
    linestyle="-",
    label="Fitted tech level (from gA_hat)"
)

ax.plot(
    df_forecast["year"],
    df_forecast["A_actual"],
    color="tab:blue",
    linestyle="--",
    marker="o",
    label="Actual tech level (where observed)"
)

ax.set_xlabel("Year")
ax.set_ylabel("Tech level (index = 1 at earliest year)")
ax.set_title("Tech Level vs Time\nActual (up to 200) and Fitted (extrapolated to 1875)")
ax.grid(True, alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# %%
# 

import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# --- 1. Rebuild the estimation sample (same as cell 19) ---

mask_est = (human_history_df["year"] >= -5000) & (human_history_df["year"] <= 200)
df_est = human_history_df.loc[mask_est, ["year", "population", "tech_growth"]].copy()
df_est = df_est.dropna(subset=["population", "tech_growth"])

df_est = df_est[df_est["tech_growth"] > 0].copy()
df_est["ln_gA"] = np.log(df_est["tech_growth"])
df_est["ln_N"]  = np.log(df_est["population"])

X = sm.add_constant(df_est[["ln_N"]])
y = df_est["ln_gA"]

model   = sm.OLS(y, X)
results = model.fit()

alpha_hat = np.exp(results.params["const"])
sigma_hat = results.params["ln_N"]

print(results.summary())
print("Estimated alpha:", alpha_hat)
print("Estimated sigma:", sigma_hat)

# --- 2. Build forecast dataset to today, and compute fitted growth ---

mask_forecast = (human_history_df["year"] >= -5000)
df_forecast = human_history_df.loc[mask_forecast, ["year", "population", "tech_growth"]].copy()

df_forecast = df_forecast.dropna(subset=["population"])
df_forecast = df_forecast[df_forecast["population"] > 0].copy()

df_forecast["ln_N"] = np.log(df_forecast["population"])
df_forecast["ln_gA_hat"] = np.log(alpha_hat) + sigma_hat * df_forecast["ln_N"]
df_forecast["gA_hat"] = np.exp(df_forecast["ln_gA_hat"])

# --- 3. Plot 1: tech growth and fitted growth vs population (to today) ---

fig, ax = plt.subplots(figsize=(8, 6))

mask_actual = df_forecast["tech_growth"].notna()
ax.scatter(
    df_forecast.loc[mask_actual, "population"],
    df_forecast.loc[mask_actual, "tech_growth"],
    color="tab:blue",
    label="Actual tech_growth"
)

df_sorted_N = df_forecast.sort_values("population")
ax.plot(
    df_sorted_N["population"],
    df_sorted_N["gA_hat"],
    color="tab:orange",
    linestyle="-",
    label="Fitted tech_growth (gA_hat)"
)

ax.set_xlabel("Population (millions)")
ax.set_ylabel("Annual log tech growth")
ax.set_title("Tech Growth vs Population\nActual (to today) and Fitted (up to year 200)")
ax.grid(True, alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# --- 4. Construct tech level paths (actual and fitted) to today ---

df_forecast = df_forecast.sort_values("year").copy()

years    = df_forecast["year"].values
gA_act   = df_forecast["tech_growth"].values
gA_fit   = df_forecast["gA_hat"].values

A_act = np.empty_like(gA_fit, dtype=float)
A_fit = np.empty_like(gA_fit, dtype=float)

A_act[0] = 1.0
A_fit[0] = 1.0

for i in range(1, len(years)):
    dt = years[i] - years[i - 1]

    # fitted tech level: always uses fitted growth
    A_fit[i] = A_fit[i - 1] * np.exp(gA_fit[i] * dt)

    # actual tech level: only where we observe growth
    if not np.isnan(gA_act[i]):
        if np.isnan(A_act[i - 1]):
            A_act[i - 1] = A_fit[i - 1]
        A_act[i] = A_act[i - 1] * np.exp(gA_act[i] * dt)
    else:
        A_act[i] = np.nan

df_forecast["A_actual"] = A_act
df_forecast["A_fitted"] = A_fit

# --- 5. Plot 2: tech level and fitted tech level vs time (to 1875) ---

fig, ax = plt.subplots(figsize=(9, 6))

ax.plot(
    df_forecast["year"],
    df_forecast["A_fitted"],
    color="tab:orange",
    linestyle="-",
    label="Fitted tech level (from gA_hat)"
)

ax.plot(
    df_forecast["year"],
    df_forecast["A_actual"],
    color="tab:blue",
    linestyle="--",
    marker="o",
    label="Actual tech level (where observed)"
)

ax.set_xlabel("Year")
ax.set_ylabel("Tech level (index = 1 at earliest year)")
ax.set_title("Tech Level vs Time\nActual and Fitted (up to year 200)")
ax.grid(True, alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# --- 1. Rebuild the estimation sample (same as before, up to 200) ---

mask_est = (human_history_df["year"] >= -5000) & (human_history_df["year"] <= 200)
df_est = human_history_df.loc[mask_est, ["year", "population", "tech_growth"]].copy()
df_est = df_est.dropna(subset=["population", "tech_growth"])

df_est = df_est[df_est["tech_growth"] > 0].copy()
df_est["ln_gA"] = np.log(df_est["tech_growth"])
df_est["ln_N"]  = np.log(df_est["population"])

X = sm.add_constant(df_est[["ln_N"]])
y = df_est["ln_gA"]

model   = sm.OLS(y, X)
results = model.fit()

alpha_hat = np.exp(results.params["const"])
sigma_hat = results.params["ln_N"]

print(results.summary())
print("Estimated alpha:", alpha_hat)
print("Estimated sigma:", sigma_hat)

# --- 2. Build forecast dataset to "today" (last year in the data) ---

last_year = human_history_df["year"].max()
print("Forecasting up to year:", last_year)

mask_forecast = (human_history_df["year"] >= -5000) & (human_history_df["year"] <= last_year)
df_forecast = human_history_df.loc[mask_forecast, ["year", "population", "tech_growth"]].copy()

df_forecast = df_forecast.dropna(subset=["population"])
df_forecast = df_forecast[df_forecast["population"] > 0].copy()

df_forecast["ln_N"] = np.log(df_forecast["population"])
df_forecast["ln_gA_hat"] = np.log(alpha_hat) + sigma_hat * df_forecast["ln_N"]
df_forecast["gA_hat"] = np.exp(df_forecast["ln_gA_hat"])

# --- 3. Graph 1: tech growth and fitted growth vs population (to "today") ---

fig, ax = plt.subplots(figsize=(8, 6))

mask_actual = df_forecast["tech_growth"].notna()
ax.scatter(
    df_forecast.loc[mask_actual, "population"],
    df_forecast.loc[mask_actual, "tech_growth"],
    color="tab:blue",
    label="Actual tech_growth"
)

df_sorted_N = df_forecast.sort_values("population")
ax.plot(
    df_sorted_N["population"],
    df_sorted_N["gA_hat"],
    color="tab:orange",
    linestyle="-",
    label="Fitted tech_growth (gA_hat)"
)

ax.set_xlabel("Population (millions)")
ax.set_ylabel("Annual log tech growth")
ax.set_title(f"Tech Growth vs Population\nActual (in-sample) and Fitted (to year {int(last_year)})")
ax.grid(True, alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# --- 4. Construct tech level paths (actual and fitted) to "today" ---

df_forecast = df_forecast.sort_values("year").copy()

years  = df_forecast["year"].values
gA_act = df_forecast["tech_growth"].values
gA_fit = df_forecast["gA_hat"].values

A_act = np.empty_like(gA_fit, dtype=float)
A_fit = np.empty_like(gA_fit, dtype=float)

A_act[0] = 1.0
A_fit[0] = 1.0

for i in range(1, len(years)):
    dt = years[i] - years[i - 1]

    # fitted tech level: always uses fitted growth
    A_fit[i] = A_fit[i - 1] * np.exp(gA_fit[i] * dt)

    # actual tech level: only where we observe growth
    if not np.isnan(gA_act[i]):
        if np.isnan(A_act[i - 1]):
            A_act[i - 1] = A_fit[i - 1]
        A_act[i] = A_act[i - 1] * np.exp(gA_act[i] * dt)
    else:
        A_act[i] = np.nan

df_forecast["A_actual"] = A_act
df_forecast["A_fitted"] = A_fit

# --- 5. Graph 2: tech level and fitted tech level vs time (to "today") ---

fig, ax = plt.subplots(figsize=(9, 6))

ax.plot(
    df_forecast["year"],
    df_forecast["A_fitted"],
    color="tab:orange",
    linestyle="-",
    label="Fitted tech level (from gA_hat)"
)

ax.plot(
    df_forecast["year"],
    df_forecast["A_actual"],
    color="tab:blue",
    linestyle="--",
    marker="o",
    label="Actual tech level (where observed)"
)

ax.set_xlabel("Year")
ax.set_ylabel("Tech level (index = 1 at earliest year)")
ax.set_title(f"Tech Level vs Time\nActual (in-sample) and Fitted (extrapolated to {int(last_year)})")
ax.grid(True, alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# $$
# \begin{equation}
# \frac{\dot A_t}{A_t} =  \alpha_t N_t^{\sigma}  A_t^{-\lambda}
# \end{equation}
# $$
#
# where the minus lamba incorporates the harvesting-the-low-hanging-fruit effect, the sigma < 1 incorporates the stepping-on-toes effect, and the time-varying alpha takes account of changing effectiveness of the means of memory, communication, and R&D
#
#
# ---
# ---

# %%
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# --- 1. Restrict sample to 1500–2025 and keep tech_growth, population ---

mask = (human_history_df["year"] >= 1500) & (human_history_df["year"] <= 2025)
df_est = human_history_df.loc[mask, ["year", "population", "tech_growth"]].copy()

# drop missing / nonpositive values needed for logs
df_est = df_est.dropna(subset=["population", "tech_growth"])
df_est = df_est[(df_est["population"] > 0) & (df_est["tech_growth"] > 0)].copy()

# logs
df_est["ln_gA"] = np.log(df_est["tech_growth"])
df_est["ln_N"]  = np.log(df_est["population"])   # N = population

# --- 2. Log–linear regression: ln gA = ln(alpha) + sigma * ln N + error ---

X = sm.add_constant(df_est[["ln_N"]])
y = df_est["ln_gA"]

model   = sm.OLS(y, X)
results = model.fit()

alpha_hat = np.exp(results.params["const"])
sigma_hat = results.params["ln_N"]

print(results.summary())
print("Estimated alpha:", alpha_hat)
print("Estimated sigma:", sigma_hat)

# fitted growth
df_est["ln_gA_hat"] = results.fittedvalues
df_est["gA_hat"]    = np.exp(df_est["ln_gA_hat"])

# --- 3. Graph 1: tech growth and fitted tech growth vs population, 1500–2025 ---

fig, ax = plt.subplots(figsize=(8, 6))

# scatter actual
ax.scatter(
    df_est["population"],
    df_est["tech_growth"],
    color="tab:blue",
    label="Actual tech_growth"
)

# fitted curve, sorted by population
df_sorted = df_est.sort_values("population")
ax.plot(
    df_sorted["population"],
    df_sorted["gA_hat"],
    color="tab:orange",
    linestyle="-",
    label="Fitted tech_growth (gA_hat)"
)

ax.set_xlabel("Population (millions)")
ax.set_ylabel("Annual log tech growth")
ax.set_title("Tech Growth vs Population, 1500–2025\nActual and Fitted (log–linear in N)")
ax.grid(True, alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# --- 4. Construct tech-level paths 1500–2025 from actual and fitted growth ---

df_path = df_est.sort_values("year").copy()

years  = df_path["year"].values
gA_act = df_path["tech_growth"].values
gA_fit = df_path["gA_hat"].values

A_act = np.empty_like(gA_fit, dtype=float)
A_fit = np.empty_like(gA_fit, dtype=float)

# normalize both at 1500 to 1
A_act[0] = 1.0
A_fit[0] = 1.0

for i in range(1, len(years)):
    dt = years[i] - years[i - 1]

    # fitted tech level always uses fitted growth
    A_fit[i] = A_fit[i - 1] * np.exp(gA_fit[i] * dt)

    # actual tech level where we have actual growth
    if not np.isnan(gA_act[i]):
        if np.isnan(A_act[i - 1]):
            A_act[i - 1] = A_fit[i - 1]
        A_act[i] = A_act[i - 1] * np.exp(gA_act[i] * dt)
    else:
        A_act[i] = np.nan

df_path["A_actual"] = A_act
df_path["A_fitted"] = A_fit

# --- 5. Graph 2: tech level and fitted tech level vs time, 1500–2025 ---

fig, ax = plt.subplots(figsize=(9, 6))

ax.plot(
    df_path["year"],
    df_path["A_fitted"],
    color="tab:orange",
    linestyle="-",
    label="Fitted tech level (from gA_hat)"
)

ax.plot(
    df_path["year"],
    df_path["A_actual"],
    color="tab:blue",
    linestyle="--",
    marker="o",
    label="Actual tech level (where observed)"
)

ax.set_xlabel("Year")
ax.set_ylabel("Tech level (index = 1 in 1500)")
ax.set_title("Tech Level vs Time, 1500–2025\nActual and Fitted (tech_growth driven by population)")
ax.grid(True, alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Modeling Rates of Population Growth
#
# * When and where and how does the demographic transition set in?

# %%
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# --- 1. Estimate on 1500–1875 only, using population ---

mask_est  = (human_history_df["year"] >= 1500) & (human_history_df["year"] <= 1875)
mask_full = (human_history_df["year"] >= 1500) & (human_history_df["year"] <= 2025)

df_est  = human_history_df.loc[mask_est,  ["year", "population", "tech_growth"]].copy()
df_full = human_history_df.loc[mask_full, ["year", "population", "tech_growth"]].copy()

# clean estimation sample for logs
df_est = df_est.dropna(subset=["population", "tech_growth"])
df_est = df_est[(df_est["population"] > 0) & (df_est["tech_growth"] > 0)].copy()

df_est["ln_gA"] = np.log(df_est["tech_growth"])
df_est["ln_N"]  = np.log(df_est["population"])

X_est = sm.add_constant(df_est[["ln_N"]])
y_est = df_est["ln_gA"]

model   = sm.OLS(y_est, X_est)
results = model.fit()

alpha_hat = np.exp(results.params["const"])
sigma_hat = results.params["ln_N"]

print(results.summary())
print("Estimated alpha:", alpha_hat)
print("Estimated sigma:", sigma_hat)

# --- 2. Apply model to full 1500–2025 window (in-sample + OOS) ---

df_full = df_full.dropna(subset=["population"])
df_full = df_full[df_full["population"] > 0].copy()

df_full["ln_N"] = np.log(df_full["population"])
df_full["ln_gA_hat"] = np.log(alpha_hat) + sigma_hat * df_full["ln_N"]
df_full["gA_hat"]    = np.exp(df_full["ln_gA_hat"])

df_full["in_sample"] = df_full["year"] <= 1875

# --- 3. Figure 1: tech growth vs population, 1500–2025, with OOS extrapolation ---

fig, ax = plt.subplots(figsize=(8, 6))

mask_actual = df_full["tech_growth"].notna()
mask_in     = mask_actual & df_full["in_sample"]
mask_out    = mask_actual & (~df_full["in_sample"])

# in-sample actual (1500–1875)
ax.scatter(
    df_full.loc[mask_in, "population"],
    df_full.loc[mask_in, "tech_growth"],
    color="tab:blue",
    label="Actual tech_growth (1500–1875)"
)

# out-of-sample actual (1875–2025), if available
if mask_out.any():
    ax.scatter(
        df_full.loc[mask_out, "population"],
        df_full.loc[mask_out, "tech_growth"],
        color="tab:green",
        marker="x",
        label="Actual tech_growth (1875–2025)"
    )

# fitted curve over full range 1500–2025
df_sorted = df_full.sort_values("population")
ax.plot(
    df_sorted["population"],
    df_sorted["gA_hat"],
    color="tab:orange",
    linestyle="-",
    label="Fitted tech_growth (model estimated 1500–1875)"
)

ax.set_xlabel("Population (millions)")
ax.set_ylabel("Annual log tech growth")
ax.set_title("Tech Growth vs Population, 1500–2025\nModel fitted on 1500–1875, extrapolated thereafter")
ax.grid(True, alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# --- 4. Figure 2: tech level vs time, 1500–2025, with OOS fitted path ---

df_full = df_full.sort_values("year").copy()

years  = df_full["year"].values
gA_act = df_full["tech_growth"].values
gA_fit = df_full["gA_hat"].values

A_act = np.empty_like(gA_fit, dtype=float)
A_fit = np.empty_like(gA_fit, dtype=float)

# normalize at 1500
A_act[0] = 1.0
A_fit[0] = 1.0

for i in range(1, len(years)):
    dt = years[i] - years[i - 1]

    # fitted tech level: always uses fitted growth, 1500–2025
    A_fit[i] = A_fit[i - 1] * np.exp(gA_fit[i] * dt)

    # actual tech level where we have data
    if not np.isnan(gA_act[i]):
        if np.isnan(A_act[i - 1]):
            A_act[i - 1] = A_fit[i - 1]
        A_act[i] = A_act[i - 1] * np.exp(gA_act[i] * dt)
    else:
        A_act[i] = np.nan

df_full["A_actual"] = A_act
df_full["A_fitted"] = A_fit

fig, ax = plt.subplots(figsize=(9, 6))

ax.plot(
    df_full["year"],
    df_full["A_fitted"],
    color="tab:orange",
    linestyle="-",
    label="Fitted tech level (1500–2025)\nmodel estimated on 1500–1875"
)

ax.plot(
    df_full["year"],
    df_full["A_actual"],
    color="tab:blue",
    linestyle="--",
    marker="o",
    label="Actual tech level (where observed)"
)

# mark the end of the estimation window
ax.axvline(1875, color="gray", linestyle=":", linewidth=1)
ax.text(1875 + 2, ax.get_ylim()[0], "End of\nestimation", va="bottom", fontsize=8)

ax.set_xlabel("Year")
ax.set_ylabel("Tech level (index = 1 in 1500)")
ax.set_title("Tech Level vs Time, 1500–2025\nModel fitted on 1500–1875, extrapolated thereafter")
ax.grid(True, alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## What We Can See
#
# * Late-Antiquity Pause
# * Mediæval Recovery
# * Early Modern Acceleration
# * Industrial Breakthrough
# * Modern Economic Growth

# %% [markdown]
# ### Comprehending the MacroStructure of Post-Bronze Post-Writing Human History
#
# <p style="text-align: right;">
#     <img src="images/2026-01-19-human-history-macrostructure.png"
#      alt="J. Bradford DeLong"
#      width="500"
#      align="right"
#      style="float:right; margin: 0 0 10px 10px;" /></p>
#
# * As of -1500: Ancient: 0.024%/year—2.4% per century...
# * As of -800: The Late-Antiquity Pause: -0.022%/year—**agrarian-era antiquity technology growth is not guaranteed**
# * As of 800-1600: Post-800 has shifted to a higher rate of growth than characteristic of "antiquity": 8%/century
# * As of 1600-1775: Commercial-Imperial era has been in full swing for a while: 25%/century
# * As of 1775-1875: The "Dover Circle" Industrial Revolution has been a thing: 90%/century
# * As of 1875-2025: MEG: 2%/year; 7.4-fold/century
#     * **Memo**: necessities, conveniences & luxuries, cultural goods, inequality—within & between societies—& domination

# %% [markdown]
# ## Econ 196 Seminar: Quantitative Long-Run Global Economic History
#
# # PRE-CLASS ASSIGNMENT: Due 2026-03-08 23:59 PST (Su): 1875: The Hinge of History?
#
# <<https://bcourses.berkeley.edu/courses/1551896/assignments/9045379>>
#
# ======
#
# **READINGS**: Mandatory:
#
# * **DeLong, J. Bradford**. 2022. "DAY 1: LECTURE NOTES: 1. Introduction: 1.1. Five Questions Surrounding the Identification of 1870 as the Hinge of History". _DeLong's Grasping Reality_. October 11. <<https://braddelong.substack.com/p/introduction-to-history-of-economic>>.
# * **DeLong, J. Bradford**. 2022. _Slouching Towards Utopia: The Economic History of the 20th Century_. New York: Basic Books. <<https://bcourses.berkeley.edu/courses/1551896/files?preview=93579591>>: Introduction, Ch. 1. Globalizing the World, & Ch. 2. Revving Up the Engine of Technology-Driven Growth.
# * **Hobsbawm, Eric**. 1994. _The Age of Extremes: The Short Twentieth Century, 1914–1991_. London: Michael Joseph. <<https://bcourses.berkeley.edu/courses/1551896/files?preview=94066813>.> Introduction: The Century: A Bird's Eye View & 19. Toward the Millennium
#
# ======
#
# **ANSWER**: the following five questions in the text-entry box (one-paragraph answers for each) at: <<https://bcourses.berkeley.edu/courses/1551896/assignments/9045379>>:
#
# 1. What do you see as the strongest argument against DeLong's claim and belief that sometime around 1870 there came the true hinge of human history?
# 2. How had political domination and distribution conflicts in the years from -3000 to 1870 made it difficult to create and sustain human institutions focused on technological and economic development?
# 3. In your view, is the shift in the rate of economic growth around 1870 more likely to have been "causally thick" or "causally thin"? Why do you think this?
# 4. What is there about the problems of slicing and tasting the economic pie so that everyone feels they have enough that makes humanity have a harder time solving those problems than the problem of baking a sufficiently large economic pie that everyone could have enough?
# 5. Eric Hobsbawm, writing thirty years ago, sees the techno-economic marvels of economic development up until 1994 as offset by the "most disturbing... disintegration of the old patterns of human social relationships, and... the snapping of the links... between past and present... the tear[ing-]up... [of] the Protestant Ethic [of]... the abstention from immediate gratification; with the ethic of hard work; with family duty and trust.... The old maps and charts which guided human beings, dingly and collectively, through life no longer represent the landscape through which we move, the sea on which we sail. In which we do not know where our journey is taking us, or even ought to take us...". This drives his conclusion that, in spite of the enormous amplification of material wealth we have seen, "the old century has not ended well". To what extent is this the same as and to what extent is this a different diagnosis of what DeLong points to when he contrasts the approach of Friedrich von Hayek, summarized as the market giveth; the market taketh away; blessed be the name of the market, and the approach of Karl Polanyi, summarized as the market is made for man, not man for the market?
#
# ---
# ---

# %% [markdown]
# # Productivity Levels & Technologies
#
# <p style="text-align: right;">
#     <img src="images/delong-picture.png"
#      alt="J. Bradford DeLong"
#      width="300"
#      height="300"
#      align="right"
#      style="float:right; margin: 0 0 10px 10px;" />
# </p>
#
# ### Readings: Mandatory:
#
# This week, as I hunt for what the sweet spot is for reading for this class, I am assigning two articles:
#
# * **Lee, Ronald**. 2003. “The Demographic Transition: Three Centuries of Fundamental Change”. _Journal of Economic Perspectives_. 17:4 (Fall), pp. 167-90. <<https://pubs.aeaweb.org/doi/pdfplus/10.1257/089533003772034943>>.
#
# * **Nordhaus, William**. 1996, “Do Real-Output and Real-Wage Measures Capture Reality? The History of Lighting Suggests Not”. In Timothy Bresnahan & Robert Gordon, eds. _The Economics of New Goods_. Chicago: University of Chicago. <<https://www.nber.org/system/files/chapters/c6064/c6064.pdf>>.
#
# **ANSWER**: the following five questions in the text-entry box (one-paragraph answers for each) at <<https://bcourses.berkeley.edu/courses/1551896/assignments/9039498>>:
#
# 1. In 1800 the world's population was about 925 million, and it had grown by 5% in the previous century. What would the world's population be today had it continued to grow at that pace. And how much larger is the world's actual population today?
# 2. Why, in Ron Lee's estimation, did the demographic transition occur?
# 3. What does Ron Lee expect to happen to the level of the human population over the next century or two?
# 4. Why does William Nordhaus believe that the quantity of photons pumped out by artificial lighting is the right way to measure the production of the commodity "useful light"?
# 5. Do you buy Nordhaus's argument that even though, in terms of our capability to produce necessities, we today are merely (merely!) sixteen times richer than our mediæval pre-industrial ancestors, in truth we are actually richer by many more orders of magnitude
#
# We will return to these questions and to these readings toward the end of today—if we have time...
#
#
# <br style="clear: both;">
#
# ---
# ---

# %% [markdown]
# # The Demographic Transition
#
# Title: The Demographic Transition: Three Centuries of Fundamental Change
# Author: Ronald Lee
# JEP 17(4), 2003
#
# * Core question: How did the mortality–fertility transition reshape population size, age structure, and economic life over the past three centuries?
# * Key claim: Since ~1800, declining mortality followed by declining fertility has transformed population growth, age distributions, family behavior, and the economic lifecycle.
#
# ---
# ---
#
# ## The Demographic Transition in Three Moves
#
# * Phase 1 – Mortality decline: Starting ~1800 in (north‑western) Europe, mortality—especially infant and child mortality—falls sharply, initially with little change in fertility.
# * Phase 2 – Population surge: With high fertility and lower mortality, population size explodes and the age structure becomes very young; dependency initially falls because working‑age cohorts are abundant.
# * Phase 3 – Fertility decline & aging: Fertility later falls toward replacement or below, population growth slows or turns negative, and age structures shift from young to old, producing population aging. •⁠•
#
# ---
# ---
#
# ## Drivers of Mortality Decline
#
# * Public health & environment: Clean water, sanitation, and better control of infectious disease (smallpox, later TB, etc.) cut mortality well before “modern medicine” becomes effective.
# * Nutrition and living standards: Rising incomes and better food distribution improve resistance to disease, interacting with public health to lower death rates.
# * Medical progress later: Vaccines, antibiotics, and clinical medicine become quantitatively important later in the transition, reinforcing earlier gains.
# * Result: Big mortality improvements at all ages, but especially infants and children, set off the demographic transition. •⁠•
#
# ---
# ---
#
# ## Drivers of Fertility Decline
#
# * Economic calculus of children: As child survival improves, parents need fewer births to achieve desired surviving children; the “insurance” motive weakens.
# * Rising costs of children: Urbanization, schooling, and foregone child labor raise the direct and opportunity costs of each child.
# * Changing norms & contraception: Ideational change (family limitation becoming legitimate) and access to birth control technologies reduce fertility at given income levels.
# * Gender & education: Rising female education and labor‑force participation are strongly associated with lower desired fertility and later childbearing. •⁠•
#
# ---
# ---
#
# ## From Young to Old Society: Changing Age Structures
#
# * Early transition – youth bulge: When mortality falls and fertility remains high, child shares of the population rise and dependency can initially increase.
# * Demographic dividend window: As fertility falls, large cohorts move into working ages; the ratio of workers to dependents rises, potentially boosting per capita income growth if employment and institutions are supportive.
# * Late transition – aging: Continued low fertility plus sustained low mortality at older ages shift the population toward the elderly, raising old‑age dependency and straining pay‑as‑you‑go pension and health systems. •⁠•
#
# ---
# ---
#
# ## Individual & Family-Level Consequences
#
# * Longer lives, longer horizons: Individuals must plan over longer lifespans, changing savings, education, and retirement behavior.
# * Fewer children, more investment per child: Parents substitute “quality” for “quantity”—spending more on each child’s education and health.
# * Changing intergenerational transfers: The shape of the economic lifecycle shifts; time and resources flow differently across generations, often mediated by public systems (pensions, schooling, health insurance) rather than only by families. •⁠•
#
# ---
# ---
#
# ## Macro Consequences: Growth, Capital, & the Welfare State
#
# * Growth and the demographic dividend: A favorable age structure (large working‑age cohorts) can raise aggregate saving, labor supply, and growth, especially in the “East Asian miracle” cases.
# * Capital accumulation & saving: With fewer children and longer retirement, life‑cycle saving behavior changes; in some phases this may raise aggregate saving and capital per worker.
# * Population aging & fiscal stress: Low fertility and longevity together create rising old‑age support ratios, pressuring pensions, health systems, and intergenerational fiscal contracts; policy responses (later retirement, higher contributions, benefit cuts, immigration) become central. •⁠•
#
# ---
# ---
#
# ## Lee’s Bottom Line
#
# * Fundamental transformation: The demographic transition is not a marginal adjustment but one of the great structural changes of the last three centuries, comparable in significance to industrialization.
# * Dual nature: It is both a success story (longer lives, smaller families, scope for more human capital) and a challenge (population aging, pension and health‑care burdens, potential for slower growth).
# * Open future: The process is incomplete—many developing countries are still moving through the transition, and advanced economies are grappling with below‑replacement fertility and rapid aging. •⁠•
#
# ---
# ---
#
# ## DeLong’s Take I: Demographic Transition as the End of Human Ensorcellment by the Devil of Malthus
#
# * Pre‑1870 world as Malthusian: For most of human history, technological improvements fed primarily into more people, not higher sustained living standards; mortality and fertility jointly kept societies “ensorcelled by the Devil of Malthus.”
# * Post‑1870 “Economic El Dorado”: After 1870, rapid technological progress and the demographic transition together allow sustained growth in income per capita; technology finally “wins its race against fecundity.” •⁠•
# * Lee as the missing chapter: In his own words, DeLong concedes that Slouching Towards Utopia pushed the demographic transition “offstage,” treating it as a simple mechanical response to higher incomes and lower infant mortality—an “inadequate treatment” of one of the most important pieces of twentieth‑century history. •⁠•
#
# ---
# ---
#
# ## DeLong’s Take II: Power, Gender, & Today’s Low-Fertility World
#
# * Beyond income–fertility mechanics: DeLong is suspicious of any story in which demographic transition is just an Oded‑Galor‑style shift from quantity to quality of children; he insists on the role of increased female social power and political struggle—“my great‑grandmother and all my sisters did this”—in driving fertility decline. ​⁠￼
# * Demography and the unfinished utopia: In his grand narrative, the twentieth century reveals that we can bake a big enough economic pie; the fact that we have not solved distribution and “living wisely and well” is the core failure. The demographic transition is central here: it both creates the possibility of sustained abundance and, via aging and the political economy of welfare states, generates new conflicts over “who gets what, when, and how.” •⁠•
# * Policy implication in DeLong’s register: For rich countries facing low fertility and rapid aging, the challenge is to use the wealth enabled by technology and the demographic transition to build institutions—around migration, family policy, gender equality, pensions, and health—that keep the social contract from cracking, rather than letting demographic anxiety fuel zero‑sum politics.
#
# ---
# ---
# ---
# ---

# %% [markdown]
# # Bill Nordhaus on the Price of Artificial Illumination, & the Puzzle of the True Rate of Economic Growth
#
# **Central question**: Do standard real GDP and real wage measures capture the true rise in living standards, or are they missing the big welfare gains from technological revolutions like artificial illumination?
#
# ### Nordhaus’s Object Lesson: From Tallow to Tungsten (and Beyond)
#
# * Service, not good: Nordhaus prices illumination (lumen‑hours), not fuel or hardware, over two centuries.
# * Technologies sequenced: Tallow candles → whale oil → gas lighting → kerosene → incandescent bulbs → fluorescents, etc.
# * Order‑of‑magnitude fall: The cost of a lumen‑hour falls by factors of thousands; a given amount of work time buys orders of magnitude more light in 1990 than in 1800.
# * Implication: Measured prices of inputs (candles, oil, electricity) largely miss the productivity explosion in the service of light. ​⁠https://lucept.com/wp-content/uploads/2014/11/william-nordhaus-the-cost-of-light.pdf
#
# ---
# ---
#
# ## Why Standard Real-Output Measures Miss the Story
#
# * Laspeyres problem: Official price indices follow input prices in a narrow bundle, holding quality and product definition fixed; they rarely re‑specify the good as “lumens” rather than “candles” or “kWh.”
# * Quality change at regime breaks: Each major lighting regime shift (gas → kerosene → electricity) brings huge jumps in efficiency, reliability, and usability that standard indices treat as small or gradual.
# * Result: Traditional real-output and real-wage measures drastically understate the decline in the “true” price of light and, hence, understate growth in real living standards. ​⁠https://lucept.com/wp-content/uploads/2014/11/william-nordhaus-the-cost-of-light.pdf
#
# ---
# ---
#
# ##Nordhaus’s Broader Claim about Economic Growth
#
# * Lighting as a microcosm: Illumination is a case study for a pervasive phenomenon: when technologies leap, measured prices lag.
# * Invisible revolutions: Similar mismeasurement likely for heating, transport, communication, information, and health—domains where the service improved more than the thing whose price we track.
# * Timing of fastest gains: For light, Nordhaus finds the largest unmeasured productivity jump roughly in the half century around the late nineteenth century; the “special century” looks even more special once you correct for this.
# * Takeaway: True long‑run growth in economic welfare is substantially higher than what national accounts report. •⁠https://lucept.com/wp-content/uploads/2014/11/william-nordhaus-the-cost-of-light.pdf
#
# ---
# ---
#
# ## DeLong on “How Fast Is Modern Economic Growth?”
#
# * Official story: Post‑Civil War U.S. productivity growth ~1.6%/year ⇒ output per worker doubles every ~44 years; three doublings since 1867. ​⁠https://www.frbsf.org/research-and-insights/publications/economic-letter/1998/10/how-fast-is-modern-economic-growth/
# * Historical comparison: Even 1770–1867 plausibly saw one doubling; 1867–today sees three by official measures. Already enormous by pre‑modern standards.
# * But…: Evidence has been mounting that this already “blazingly fast” growth is understated, for exactly Nordhaus‑type reasons: we misprice new goods, new qualities, and entirely new activities.
# * FRBSF hook: The Economic Letter explicitly uses Nordhaus’s illumination work as a canonical example of how standard productivity measures miss big welfare gains. <<https://www.frbsf.org/research-and-insights/publications/economic-letter/1998/10/how-fast-is-modern-economic-growth/>>
#
# ---
# ---
#
# ## DeLong’s “True Rate” View: Off the Scale of 19th-Century Imagination
#
# * Bellamy thought experiment: In Looking Backward, being able to dial up live music into your parlor would have been “the limit of human felicity”; modern recorded music and streaming services go well beyond that imagined ceiling. ​⁠https://www.frbsf.org/research-and-insights/publications/economic-letter/1998/10/how-fast-is-modern-economic-growth/
# * Richest then vs. average now: Even the Morgans and Rothschilds lacked antibiotics, central heating, modern entertainment, telephones, IT; they simply could not buy today’s consumption bundle at any price.
# * Conclusion: From the vantage point of 1867, the material standard of living of an average American today sits “off the scale” of what they could even conceptualize, implying true growth far exceeds the 8x increase in measured GDP per worker. •⁠https://www.frbsf.org/research-and-insights/publications/economic-letter/1998/10/how-fast-is-modern-economic-growth/
# * But distribution matters: Even if the average household has seen off‑the‑scale gains, those at the bottom who still spend most of their budget on basic food, shelter, and clothing may not have captured anything like that multiple; mismeasurement is larger higher up the income distribution. •⁠https://www.frbsf.org/research-and-insights/publications/economic-letter/1998/10/how-fast-is-modern-economic-growth/
#
# ---
# ---
#
# ## How Nordhaus’s Light Fits into DeLong’s Big Story
#
# * Lighting as emblem of the 1870–1910 break: Nordhaus’s finding that the price of illumination collapses around the turn of the twentieth century dovetails perfectly with DeLong’s claim that a true 1870 watershed sees the world escape the Malthusian devil. ​⁠https://www.frbsf.org/research-and-insights/publications/economic-letter/1998/10/how-fast-is-modern-economic-growth/
# * From “goods” to “capabilities”: Both Nordhaus and DeLong argue that we ought to measure growth in terms of what people can do—see at night, listen to music, travel, avoid infection—rather than the nominal value of the physical objects they buy.
# * Shared bottom line: The official productivity series already show an unprecedented acceleration after 1870; once you fold in Nordhaus‑style service measures and DeLong’s concerns about new goods and consumer surplus, the true rate of growth of human technological capability is higher still.
#
# ---
# ---
#
# ## DeLong’s Assessment: What the Price of Light Teaches Us
#
# * On measurement: Nordhaus demonstrates that even in a seemingly simple domain like lighting, conventional real-output and real-wage measures dramatically understate progress; extend that logic across all major technologies and modern measured growth is a lower bound, not a best estimate.
# * On periodization: The magnitude and timing of the lighting revolution strengthen the case for a “long twentieth century” beginning around 1870, with a discrete jump in the underlying rate of technological change and welfare growth. ​⁠https://braddelong.substack.com/p/brad-delongs-history-of-economic
# * On welfare and policy: Recognizing that true growth is faster than the national accounts say does not make distributive conflict or stagnation anxieties go away—if anything, it sharpens them: the pie has grown even more than we thought, and yet its slicing (and the treatment of environmental and social externalities) remains our central failure.
#
# ---
# ---
#
# - William D. Nordhaus, “Do Real-Output and Real-Wage Measures Capture Reality? The History of Lighting Suggests Not,” in The Economics of New Goods (1997), argues that standard real-output and real-wage measures substantially understate true growth.
#
# - Conventional measures show roughly a 15‑fold increase in rich‑country GDP per capita and productivity since ~1800, but Nordhaus’s lighting-based calculations suggest a much larger effective rise in real wages—on the order of 20‑fold to 30,000‑fold, depending on how you measure welfare.
#
# - Nordhaus decomposes 1991 consumption into three categories: about 28% “run‑of‑the‑mill” goods, 36% “seismically active” since 1800 (huge quality/price shifts), and 37% categories that had no affordable counterpart in 1800, raising deep questions (e.g., via Dixit‑Stiglitz) about how to aggregate utility across old and new varieties.
#
# - Using illumination as a case study, Nordhaus finds about a 5,000‑fold fall in the price of light since 1800; because lighting had taken 1–5% of household budgets in 1800, a 100‑fold bias in the CPI for light accumulates into a major understatement of long‑run growth.
#
# - The piano/music example illustrates service vs. good pricing: the labor‑time cost of a Steinway fell from ~2,400 worker‑hours a century ago to ~1,100 today, but the labor‑time cost of the capability to listen to music at home fell from ~2,400 hours to perhaps ~10 hours (streaming via a smartphone), implying roughly a 240‑fold gain in access to that capability.
#
# - Edward Bellamy’s Looking Backward is used to make the welfare point vivid: for a late‑19th‑century utopian, simply dialing one of four live orchestras on a speakerphone would have represented “the limit of human felicity,” yet modern consumers treat far superior, on‑demand, effectively infinite recorded music as mundane.
#
# - Extending Nordhaus’s logic, long‑run service‑based price indices would show much faster growth than commodity‑based ones; Nordhaus’s illumination series implies about a 10,000‑fold decline in the real labor‑time cost of light over the past century, versus only a 10‑fold decline captured by standard indices.
#
# - Nordhaus’s best guess is that standard statistics understate “true” economic growth since 1800 by roughly 0.5–1.4 percentage points per year, implying that real wages since 1900 may have risen by a factor between 20 and 100 rather than by the much smaller multiples implied by official data.
#
# - A time‑travel thought experiment reinforces credibility: even placed in the outer elite circle of 1890 with an income 64× median, a modern upper‑middle‑class family would feel poor because they would lack three crucial service bundles we now take for granted—modern health care, utility infrastructure and appliances, and information/communication/entertainment technologies.
#
# - The death of Nathan Mayer Rothschild (from an abscess curable today with a few dollars’ worth of antibiotics), the crippling of FDR by polio, and the absence of modern communications all underscore the asymmetry: in many life‑and‑death or quality‑of‑life dimensions, even the richest in 1890 could not purchase what an average household now receives as part of everyday life, which is precisely the kind of welfare gain standard GDP and wage measures fail to capture.
