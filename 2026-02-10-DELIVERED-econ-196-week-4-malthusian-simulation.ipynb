# %% [markdown]
# ## Econ 196 Seminar: Quantitative Long-Run Global Economic History
#
# # WEEK 4: Malthusian Agrarian-Age Economies :: As Delivered
#
# <p style="text-align: right;">
#     <img src="images/delong-picture.png"
#      alt="J. Bradford DeLong"
#      width="400"
#      height="400"
#      align="right"
#      style="float:right; margin: 0 0 10px 10px;" />
# </p>
#
# ### J. Bradford DeLong :: delong@econ.berkeley.edu brad.delong@gmail.com delong@hey.com :: +1-925-708-0467
#
# ----
#
# ### Places to look for course files:
#
# ##### <<https://bcourses.berkeley.edu/courses/1551896>>
# ##### <<https://braddelong.substack.com/t/quantitative-long-run-global-economic>>
# ##### <<https://braddelong.substack.com/p/quantitative-long-run-global-economic>>
# ##### <<https://substack.com/home/post/p-184363836>>
#
# ----
#
# * Tu 1-3 Evans 560
# * Th 1-3 Zoom <<https://berkeley.zoom.us/j/7744601602>>
#
# **Course Welcome Email**: <<https://bcourses.berkeley.edu/courses/1551896/discussion_topics/7205916?is_announcement=true>>
#
# <br style="clear: both;">
#
# **And**:
#
# * Berkeley nbgitpuller: <[https://chromewebstore.google.com/detail/datahub-link-generator/ijbgangngghdanhcnaliiobbiffocahf?hl=en](https://chromewebstore.google.com/detail/datahub-link-generator/ijbgangngghdanhcnaliiobbiffocahf?hl=en)\>
#
# * Download DeLong 2025-12-27 current working github repository: <[https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https://github.com/braddelong/working\_20251227&urlpath=lab/tree/working\_20251227/](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https://github.com/braddelong/working_20251227&urlpath=lab/tree/working_20251227/)\>
#
# ---
# ---

# %% [markdown]
# # Econ 196 Seminar: Quantitative Long-Run Global Economic History
#
# <p style="text-align: right;">
#     <img src="images/delong-picture.png"
#      alt="J. Bradford DeLong"
#      width="300"
#      height="300"
#      align="right"
#      style="float:right; margin: 0 0 10px 10px;" />
# </p>
#
# * WEEK 1: Jan 20: Introduction & human population
# * WEEK 2: Jan 27: Productivity levels & technologies
# * WEEK 3: Feb 3: Human evolution, effective population size, & high patriarchy.
# * WEEK 4: Feb 10: Poor agrarian-age Malthusian societies **<---**
# * WEEK 5: Feb 17: Societies of domination: land & seaborne agrarian-age empires.
# * WEEK 6: Feb 24: The post-1500 Imperial-Commercial Age
# * WEEK 7: Mar 3: 1775-1875 in the "Dover Circle": The British Industrial Revolution
# * WEEK 8: Mar 10: The Post-1870 growth explosion: quantifying the prosperity hockey stock.
# * WEEK 9: Mar 17: Reversals of Fortune: colonial origins & cross-nation inequality
# * WEEK 10: Mar 31: The development of underdevelopment
# * WEEK 11: Apr 7: The current spread of wealth across nations, & prospects for further growth acceleration (or deceleration)
# * WEEK 12: Apr 14: Schumpeterian unbalanced growth and political economy
# * WEEK 13: Apr 21: The Fermi paradox: & the future of humanity
# * WEEK 14: Apr 28: Hicks Lecture…
#
# <br style="clear: both;">
#
# .
#
# .
#
#
#
# ---
# ---

# %% [markdown]
# ## The Biggest Picture
#
# <img src="images/2026-02-10-human-economic-history.png" />
#
# ---
# ---

# %% [markdown]
# ## Modeling & Simulating a Malthusian Economy:
#
# In the Old Days—even as recently as five years ago—at this point we would have sat down and spent a long time mathymathing the complex behavior of a very simple economic model for our pre-modern Malthusian economy. The model would have had four equations.
#
# The first and second equations are simply definitions:
#
# > $ \frac{1}{y} \frac{dy}{dt}=g $
#
# > $ \frac{1}{L} \frac{dL}{dt} = n $
#
# The first of these states that the proportional growth rate of living standards and productivity levels—the proportional growth rate of the output per worker y variable on the left-hand side—is equal to g, g for growth. The second says that the proportional growth rate of population and the labor force variable L, L for labor, on the right-hand side is equal to n, n for numbers.

# %% [markdown]
# The third and fourth equations are behavioral relationships:
#
# > $ g = h - n/\gamma $
#
# > $ n = \beta \left( \frac{y}{y^{sub}\phi}  - 1 \right) $
#
# The third says that g—the proportional growth rate of the efficiency of labor, of living standards and productivity levels—on the left-hand side, is equal to:
#
# * the proportional rate of growth h of human ideas about technology,
# * minus the proportional rate of growth of population and the labor force n
# * divided by a parameter ɣ that tells us how salient ideas about technology are in generating productivity vis-à-vis resource scarcity.
#
# It is human ingenuity versus resource scarcity. And resource scarcity is made more dire by population increases.
#
# If we were focusing on math, we would do calculus things and see:
#
# > $ \frac{d}{dt} \left(\frac{Y}{L}\right)^* = 0 $ whenever $ h - \frac{n}{\gamma} = 0 $
#
# > $ n^{*mal} = \gamma h $
#
# is the population growth rate at which the efficiency of labor and living standards are constant: $ \frac{d}{dt} \left(\frac{Y}{L}\right)^* = 0 $
#
# When population is growing at the rate $ n^{*mal} $, the efficiency of labor—and thus the steady-state growth-path level of production per worker $ Y/L $—is constant.
#
# This captures the idea that even though human technology was advancing over the more than five millennia before the Industrial Revolution, living standards were not because the potential benefits from technology and organization for productivity were offset by the productivity-diminishing effects of smaller farm sizes and more costly other natural resources to feed and provide for the growing population.
#
# In any previous decade, all this would have been essential and crucial.
#
# But it is not essential for us here and now.
#
# ---
# ---

# %% [markdown]
# The fourth equation says that the population growth rate variable n on the left-hand side will be such that population will grow if living standards y are above, and shrink if living standards are below, some “subsistence” level y^{sub}, and also on the fraction $ 1/\phi $ of production that is devoted to necessities, not conveniences and luxuries, and thus enters into reproductive and survival fitness.
#
# How much?
#
# That depends on a parameter β that tells us how responsive fertility and mortality are to want and deprivation. Twice as big a gap between living standards and subsistence will produce twice as fast a population response. As people get poorer, fertility drops: women become sufficiently skinny that ovulation becomes hit-or-miss. And as people get poorer, mortality rises: it is not just that some people starve to death, it is that the malnourished have compromised immune systems, and malnourished children, especially, are easily carried off by the common cold:
#
# > $ \frac{dL/dt}{L} = \frac{d\ln(L)}{dt} = n = \beta  \left( \frac{y}{\phi y^{sub}}-1 \right) $
#
# Then for population to be growing at its Malthusian rate:
#
# > $ \gamma h = \beta \left(\frac{1}{\phi}\right) \left( \frac{y}{y^{sub}}- \phi \right)  $
#
# > $ y^{*mal} = \phi y^{sub} \left( 1 + \frac{ n^{*mal}}{\beta}\right) = \phi y^{sub} \left( 1 + \frac{ \gamma h}{\beta}\right) $
#
# Note that this fertility behavior only holds for poor populations.
#
# When populations grow rich and literate enough—and when women acquire enough social power—human societies undergo the demographic transition: women limit their pregnancies to the number of children they desire, confident that they will pretty much all survive to outlive them. Beyond a certain income level, this no longer holds. But it did hold up until well after the start of the Industrial Revolution.
#
# ---
# ---

# %% [markdown]
# But we can take a different approach than using symbolic mathymath:

# %%
# %matplotlib inline

# %%
import numpy as np               # math package
import matplotlib.pyplot as plt  # plotting package
import random as rnd             # random number package

# %%
g = []                           # time-series list for productivity growth
n = []                           # time-series list for population growth
epsilon = []                     # uncorrelated random shocks to population
L = [1]                          # time-series list for population & labor force level
y = [1.25]                       # time-series list for productivity & living standard level

h = 0.0005                       # annual rate of technological progress
gamma = 2                        # salience of ideas vis-à-vis resources in determining productivity
beta = 0.025                     # annual response of population growth to relative living standards

for t in range(999):                                        # loop through time for 1000 years
    epsilon = epsilon + [rnd.normalvariate(0, 0.02)]        # calculate this year's population shock
    n = n + [beta * (y[t] - 1) + epsilon[t]]                # calculate this year's population growth rate
    g = g + [h - n[t]/gamma + rnd.normalvariate(0, 0.0005)] # calculate this year's productivity change
    y = y + [y[t]*np.exp(g[t])]                             # calculate this year's productivity level
    L = L + [L[t]*np.exp(n[t])]                             # calculate this year's population level

# %%
fig, ax = plt.subplots()
ax.set_xlabel("Population (L)")
ax.set_ylabel("Living standards (y)")
ax.plot(L, y)

plt.show()

# %% [markdown]
# ### Clark Estimates:
#
# English working-class real wages and population, 1204-1870
#
# <img src="images/2026-02-10-clark-wages-population.png" />

# %%
tseries = range(1000)      # set up a time-series list of years for the horizontal axis


fig, ax = plt.subplots()   # open a portal for graphs

ax.plot(tseries, L, y)     # plot living standards and population over time
ax.set_xlabel("Years")
ax.set_ylabel("Living Standards & Population")

plt.show()

# %% [markdown]
# <img src="images/2026-02-10-extreme-poverty.png" />

# %% [markdown]
# <img src="images/2026-02-10-subsistence-european-cities-ex-london-amsterdam-antwerp.png">

# %% [markdown]
# ## Malthusian Agrarian-Age Economies
#
# ### Readings:
#
# Start with a relatively “humanistic” and very short summary of my view of the situation from (at the latest) the year -3000 up to 1500 and beyond, in much of the world:
#
# 1.  **DeLong J. Bradford**. 2024. “The Great Agrarian-Age Vine-&-Fig Tree Shortage”. June 18. <[https://braddelong.substack.com/p/hoisted-from-the-archives-ensorcelled](https://braddelong.substack.com/p/hoisted-from-the-archives-ensorcelled)>.
#
# Then go into the numbers and the models:
#
# * **DeLong J. Bradford**. 2023. “Ensorcelled by the Devil of Malthus”. _DeLong’s Grasping Reality_. July 2. <[https://braddelong.substack.com/p/ensorcelled-by-e-devil-of-malthus](https://braddelong.substack.com/p/ensorcelled-by-e-devil-of-malthus)>.
#
# * **DeLong, J. Bradford**. 2023. “DAY 3: LECTURE NOTES: 2. Ensorcelled by þe Devil of Malthus: 2.1. The Logic of the Malthusian Economy.” _DeLong’s Grasping Reality_. January. <[https://braddelong.substack.com/p/day-3-lecture-notes-the-logic-of](https://braddelong.substack.com/p/day-3-lecture-notes-the-logic-of)\>.
#
# * **DeLong, J. Bradford**. 2023. “LECTURE NOTES: Lessons from Simulating a Malthusian Economy.” _DeLong’s Grasping Reality_. <[https://braddelong.substack.com/p/lecture-notes-lessons-from-simulating](https://braddelong.substack.com/p/lecture-notes-lessons-from-simulating)\>.
#
# * **DeLong J. Bradford**. 2023. “1. Guesstimating Typical Living Standards in the Agrarian Age”. _DeLong’s Grasping Reality._ September 28. <[https://braddelong.substack.com/p/1-guesstimating-typical-living-standards](https://braddelong.substack.com/p/1-guesstimating-typical-living-standards)\>.
#
#
# Plus there is a debate—one that I (naturally) think I won:
#
# *   **DeLong, J. Bradford**. 2025. “Yes: Pre‑Modern Economies Were Meaningfully ‘Malthusian’ (Which Does Not Mean Incomes Were Stable).” _DeLong’s Grasping Reality_. February 4. <[https://braddelong.substack.com/p/hoisted-from-the-archives-yes-pre](https://braddelong.substack.com/p/hoisted-from-the-archives-yes-pre)\>.
#
# With my notes referring to:
#
# * **Clark, Gregory.** 2007\. “Living Standards”. Chapter 3 in: **Clark, Gregory.** 2007. _A Farewell to Alms: A Brief Economic History of the World._ Princeton: Princeton University Press. [https://www.jstor.org/stable/j.ctt7srwt](https://www.jstor.org/stable/j.ctt7srwt)<[https://bcourses.berkeley.edu/files/93800462/](https://bcourses.berkeley.edu/files/93800462/)\>
#
# * **Guthmann, Rafael R**. 2023. “The Great Waves in Economic History.” _Rafael’s Commentary_. February 20. <[https://rafaelrguthmann.substack.com/p/the-great-waves-in-economic-history>](https://rafaelrguthmann.substack.com/p/the-great-waves-in-economic-history>)\>.
#
# * **Chatterjee, Shoumitro & Tom Vogl**. 2018. “Escaping Malthus: Economic Growth and Fertility Change in the Developing World”. A_merican Economic Review_. 108:6 (June), pp. 1440–67. <[https://www.aeaweb.org/articles?id=10.1257/aer.20170748](https://www.aeaweb.org/articles?id=10.1257/aer.20170748)\>.
#
# And also:
#
# * **Ruter, Tibor**. 2026. "Extreme poverty before capitalism wasn’t as prevalent as you think". _Political Economy, Stats, & Society_. February 9. <<https://statsandsociety.substack.com/p/extreme-poverty-before-capitalism>>.
#
# * **Bouscasse, Paul, Emi Nakamura, & Jón Steinsson**. 2025. “When Did Growth Begin? New Estimates of Productivity Growth in England from 1250 to 1870.” _Quarterly Journal of Economics_ 140:2 (June), pp. 835–888. <<https://academic.oup.com/qje/article/139/4/2579/7690176>>.
#
# * **Clark, Gregory.** 2007\. “The Logic of the Malthusian Economy”. Chapter 2 in: **Clark, Gregory.** 2007. _A Farewell to Alms: A Brief Economic History of the World._ Princeton: Princeton University Press. <[https://bcourses.berkeley.edu/files/93800463/](https://bcourses.berkeley.edu/files/93800463/)\> <[https://www.jstor.org/stable/j.ctt7srwt](https://www.jstor.org/stable/j.ctt7srwt)>.
#
# * **Clark, Gregory.** 2007\. “Fertility”. Chapter 4 in: **Clark, Gregory.** 2007. _A Farewell to Alms: A Brief Economic History of the World._ Princeton: Princeton University Press. <[https://bcourses.berkeley.edu/files/93800461/](https://bcourses.berkeley.edu/files/93800461/)>.
#
# * **Clark, Gregory.** 2007\. “Life Expectancy”. Chapter 5 in: **Clark, Gregory.** 2007. _A Farewell to Alms: A Brief Economic History of the World._ Princeton: Princeton University Press. <[https://bcourses.berkeley.edu/files/93800460/](https://bcourses.berkeley.edu/files/93800460/)> <[https://www.jstor.org/stable/j.ctt7srwt](https://www.jstor.org/stable/j.ctt7srwt)>.
# * **Wikipedia**. 2025. **“**Malthusianism**”.** <[https://en.wikipedia.org/wiki/Malthusianism](https://en.wikipedia.org/wiki/Malthusianism)\>.
#
# * **CORE.** 2018. **“**Econ Handout: The Economics of the Malthusian Trap”. <[⁠https://www.core-econ.org/wp-content/uploads/asgarosforum/27/MALTHUS-Reading.pdf](https://www.core-econ.org/wp-content/uploads/asgarosforum/27/MALTHUS-Reading.pdf)\>.
#
# And looking forward to post-1500 or so:
#
# * **Max Roser.** 2020\. “Breaking out of the Malthusian trap: How pandemics allow us to understand why our ancestors were stuck in poverty”, _Our World in Data_. <[⁠https://ourworldindata.org/breaking-the-malthusian-trap](https://ourworldindata.org/breaking-the-malthusian-trap)\>.

# %% [markdown]
# ### ANSWER: the following six questions in the text-entry box (one-paragraph answers for each) at <<https://bcourses.berkeley.edu/courses/1551896/assignments/9045328>>:
#
# 1. **Land and diminishing returns**: Why is a fixed factor like land central to Malthusian dynamics, and how does that assumption generate the wage‑population feedback highlighted in the readings?
#
# 2. **Demographic response**: Describe the mechanisms by which fertility and mortality respond to changes in real income in the pre‑modern settings discussed. Which margin (fertility vs mortality) seems more important in the examples you read?
#
# 3. **Luxuries and norms**: How can rising demand for “luxuries” or shifts in social norms (e.g., later age at marriage) raise average living standards in a Malthusian world without implying an escape from the Malthusian regime?
#
# 4. **Inequality within Malthusian systems**: How do the readings suggest elite living standards and mass living standards can move differently under Malthusian constraints, and what implications does that have for interpreting archaeological or literary evidence?
#
# 5. **Consider Guthmann and DeLong**. In what senses do you think DeLong is too full of himself, and needs to rethink his position and move closer to Guthmann's non-Malthusian take on global economic history in the long -3000 to 1500 agrarian age?
#
# 6. **Consider Chatterjee and Vogl**: what do you think could go wrong with how the world works over the next twenty-five years that could restore the relevance of Malthusian models and thinking to understanding significant parts of our world?

# %% [markdown]
# ### The Class Thinks:
#
# **1\. Land, fixed factors, and the wage–population loop:** The story told is the strong Malthusian one. Land is treated as the central fixed factor in an agrarian economy: as population rises on a fixed land base, marginal product of labor falls, so output per worker and thus real wages decline. When wages are temporarily pushed up—by technology, luck, institutions, or good harvests—better nutrition, health, and earlier marriage raise population growth; more people then dilute the land–labor ratio and push wages back down toward subsistence.
#
# Also strongly noted:
#
# *   Technological or institutional improvements mostly show up as **higher population, not permanently higher wages**.
#
# *   The Clark–DeLong setup is understood as a feedback loop: income → demographic response → land constraint → income again.
#
#
# \======
#
# **2\. Fertility vs. mortality as adjustment margins:** It is important to distinguish:
#
# *   **Mortality:** Higher incomes improve nutrition and disease resistance, sharply lowering death rates—especially infant and child mortality. Low incomes increase vulnerability to famine, disease, and epidemics. Plagues and famines are fast, dramatic “positive checks”.
#
# *   **Fertility:** Higher incomes allow earlier and more universal marriage, more births within marriage, and better maternal health; low incomes delay or prevent marriage and sometimes suppress ovulation through malnutrition. Preventive checks (late marriage, lower marital fertility) operate more slowly, often through norms.
#
#
# On which margin “matters more,” there is a split:
#
# *   A large number say **mortality dominates in the short run**—crises quickly reset populations.
#
# *   Several (especially those thinking with Clark) stress **fertility and marriage norms as key to long‑run equilibrium living standards**: societies with strong preventive checks (late marriage) can sustain higher incomes at the Malthusian steady state.
#
# *   Most end up with the nuanced view: both margins matter, but mortality drives volatility, fertility shapes the long‑run level.
#
#
# \======
#
# **3\. Luxuries, norms, and higher living standards without escape:** There is broad convergence to Malthus’s position: on the idea that you can raise equilibrium living standards _within_ a Malthusian world by weakening the translation of higher income into more surviving children:
#
# *   If households devote more income to **luxury or status consumption** (better housing, clothing, food variety, comfort, leisure), less of the surplus goes into child quantity.
#
# *   If norms push **later marriage, smaller families, or higher “required” standard before forming a household**, fertility at any given wage is lower.
#
#
# This combination lets wages settle at a **higher Malthusian equilibrium**: fewer people share the same land, so those who exist consume more. But everyone grasps that this does not break the regime: the core logic—income affects demographic behavior, which interacts with a fixed factor to limit per‑capita income—remains intact.
#
# But it is a higher plateau, not an escape ramp.
#
# \======
#
# **4\. Inequality: elites vs. masses and evidence problems:** On inequality:
#
# *   Elites control land, taxation, rents, and coercive power, so they can appropriate a rising share of surplus as population grows. Mass wages are pinned near subsistence, while elite consumption (palaces, luxury goods, art, education, stature/height) can rise.
#
# *   Some note that even elites face constraints (urban disease, violence), but still live vastly better than peasants.
#
# *   Many explicitly warn that **archaeological and literary evidence is strongly elite‑biased**: big houses, rich burials, monumental architecture, and literary celebrations of opulence say much about the extraction machine and very little about median living standards.
#
# *   The common takeaway: impressive cultural or material remains often signal **high inequality**, not broad prosperity.
#
#
# \======
#
# **5\. DeLong vs. Guthmann: is “Malthusian” doing too much work?:** The vibe is that I have overstated things::
#
# *   Malthusian dynamics are powerful and pervasive in -3000 to 1500.
#
# *   But I am too **totalizing**. Perhaps I treat “Malthusian” as a label that can rationalize almost any pattern—long upswings become “waves in a trap” rather than qualitatively distinct growth episodes.
#
# *   Guthmann emphasizes **heterogeneity, structural change, and long efflorescences**: trade, institutions, urbanization, and state capacity that seem to raise per‑capita incomes for centuries, even if not indefinitely compounding.
#
# *   The implicit advice: keep Malthusian logic as a **baseline organizing framework**, but grant Guthmann more space—acknowledging genuine, region‑specific, and temporally extended improvements in living standards, “efflorescences”—not treating all of them as mere random noise around a flat trend.
#
#
# \======
#
# **6\. Chatterjee–Vogl and Malthusian relevance in the next 25 years:** Many developing countries have “escaped” classic Malthusian dynamics because rising income is now associated with **lower fertility**, not higher. But perhaps there will be regressions: Possibilities to flag:
#
# *   **Climate change and environmental degradation** reducing effective land productivity (crop failures, water stress, ecological damage), turning land and other natural resources back into binding constraints.
#
# *   **Pandemics, wars, and state failure** undermining health systems, disrupting trade, and raising mortality, especially in vulnerable regions.
#
# *   **Stalling of the demographic transition**: if income growth slows, education and human‑capital improvements stall, or norms shift such that fertility stops falling, then population pressure could again erode per‑capita gains.
#
#
# There will not be a global return to a full Malthusian trap. Instead, they see Malthusian logic potentially re‑emerging as **locally powerful** in fragile states and regions: growth showing up as population pressure and resource stress rather than as durable improvements in average living standards.
#
# \=====
#
# The canonical Malthusian model is powereful. But be appropriately cautious about elite‑skewed evidence. And there is definitely space for a richer account focused in “efflorescences”, in which the Malthusian model is the backbone but not the entire skeleton of pre‑modern economic history.

# %% [markdown]
# <img src="images/2026-02-03-bowles-fochesato.png" />

# %% [markdown]
# <img src="images/2026-02-10-guthmann-total-urban-population.png" />
#
# <img src="images/2026-02-10-guthmann-urbanization.png" />
